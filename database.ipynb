# %%
import sqlite3
import os
import random
from faker import Faker

# %%
fake = Faker()

class ATSDatabase:
    def __init__(self, db_file='atsdatabase.db'):
        self.conn = sqlite3.connect(db_file)
        self.cursor = self.conn.cursor()
        self.create_tables()

    def create_tables(self):
        self.cursor.execute('''CREATE TABLE IF NOT EXISTS applicantprofile (
            applicant_id INTEGER PRIMARY KEY AUTOINCREMENT,
            first_name TEXT,
            last_name TEXT,
            date_of_birth TEXT,
            address TEXT,
            phone_number TEXT
        )''')

        self.cursor.execute('''CREATE TABLE IF NOT EXISTS applicationdetail (
            detail_id INTEGER PRIMARY KEY AUTOINCREMENT,
            applicant_id INTEGER NOT NULL,
            applicant_role TEXT,
            cv_path TEXT,
            FOREIGN KEY (applicant_id) REFERENCES applicantprofile(applicant_id)
        )''')

        self.conn.commit()

    def add_applicant(self, first_name, last_name, date_of_birth, address, phone_number):
        self.cursor.execute('''INSERT INTO applicantprofile (first_name, last_name, date_of_birth, address, phone_number)
                               VALUES (?, ?, ?, ?, ?)''', (first_name, last_name, date_of_birth, address, phone_number))
        self.conn.commit()

    def get_applicant_id(self, first_name, last_name):
        self.cursor.execute('''SELECT applicant_id FROM applicantprofile WHERE first_name=? AND last_name=?''', (first_name, last_name))
        result = self.cursor.fetchone()
        if result:
            return result[0]
        else:
            return None

    def get_or_create_applicant(self, first_name, last_name, date_of_birth="", address="", phone_number=""):
        applicant_id = self.get_applicant_id(first_name, last_name)
        if not applicant_id:
            self.add_applicant(first_name, last_name, date_of_birth, address, phone_number)
            applicant_id = self.cursor.lastrowid
        return applicant_id

    def add_application(self, applicant_id, applicant_role, cv_path):
        self.cursor.execute('''INSERT INTO applicationdetail (applicant_id, applicant_role, cv_path)
                               VALUES (?, ?, ?)''', (applicant_id, applicant_role, cv_path))
        self.conn.commit()

    def save_cv_to_database(self, first_name, last_name, applicant_role, cv_path):
        date_of_birth = fake.date_of_birth(minimum_age=18, maximum_age=60).strftime("%Y-%m-%d")
        address = fake.address().replace('\n', ', ')
        phone_number = fake.phone_number()

        applicant_id = self.get_or_create_applicant(first_name, last_name, date_of_birth, address, phone_number)
        self.add_application(applicant_id, applicant_role, cv_path)

    def get_all_applicants(self):
        self.cursor.execute('SELECT * FROM applicantprofile')
        return self.cursor.fetchall()

    def get_all_applications(self):
        self.cursor.execute('SELECT * FROM applicationdetail')
        return self.cursor.fetchall()

    def update_applicant(self, applicant_id, first_name, last_name, date_of_birth, address, phone_number):
        self.cursor.execute('''UPDATE applicantprofile
                               SET first_name=?, last_name=?, date_of_birth=?, address=?, phone_number=?
                               WHERE applicant_id=?''', (first_name, last_name, date_of_birth, address, phone_number, applicant_id))
        self.conn.commit()

    def delete_applicant(self, applicant_id):
        self.cursor.execute('DELETE FROM applicantprofile WHERE applicant_id=?', (applicant_id,))
        self.conn.commit()

    def update_application(self, detail_id, applicant_id, applicant_role, cv_path):
        self.cursor.execute('''UPDATE applicationdetail
                               SET applicant_id=?, applicant_role=?, cv_path=?
                               WHERE detail_id=?''', (applicant_id, applicant_role, cv_path, detail_id))
        self.conn.commit()

    def delete_application(self, detail_id):
        self.cursor.execute('DELETE FROM applicationdetail WHERE detail_id=?', (detail_id,))
        self.conn.commit()

    def close(self):
        self.conn.close()

# %%
def read_file(root_dir):
    ats_db = ATSDatabase()  

    first_names = ['John', 'Supri', 'Jane', 'Alex', 'Emily', 'Asep', 'Jajang', 'Chris', 'Katie', 'Dadang', 'Michael', 'Sara', 'Cecep', 'David', 'Laura']
    last_names = ['Smith', 'Saepuloh', 'Johnson', 'Williams', 'Suherman', 'Brown', 'Jones', 'Garcia', 'Sumarna', 'Miller', 'Davis', 'Santosa', 'Martinez', 'Hernandez']
    
    for category in os.listdir(root_dir):
        category_path = os.path.join(root_dir, category)

        if os.path.isdir(category_path): 
            print(f"Processing category: {category}")

            pdf_files = [f for f in os.listdir(category_path) if f.endswith('.pdf')][:20]

            for pdf_file in pdf_files:
                pdf_path = os.path.join(category_path, pdf_file)
                print(f"Processing CV: {pdf_file}")

                ats_db.save_cv_to_database(first_name=random.choice(first_names), 
                                            last_name=random.choice(last_names), 
                                            applicant_role=category, 
                                            cv_path=pdf_path)

    ats_db.close()

# %%
read_file('archive\data\data')
# Out:
# Processing category: ACCOUNTANT
# Processing CV: 10554236.pdf
# Processing CV: 10674770.pdf
# Processing CV: 11163645.pdf
# Processing CV: 11759079.pdf
# Processing CV: 12065211.pdf
# Processing CV: 12202337.pdf
# Processing CV: 12338274.pdf
# Processing CV: 12442909.pdf
# Processing CV: 12780508.pdf
# Processing CV: 12802330.pdf
# Processing CV: 13072019.pdf
# Processing CV: 13130984.pdf
# Processing CV: 13294301.pdf
# Processing CV: 13491889.pdf
# Processing CV: 13701259.pdf
# Processing CV: 14055988.pdf
# Processing CV: 14126433.pdf
# Processing CV: 14224370.pdf
# Processing CV: 14449423.pdf
# Processing CV: 14470533.pdf
# Processing category: ADVOCATE
# Processing CV: 10186968.pdf
# Processing CV: 10344379.pdf
# Processing CV: 10659182.pdf
# Processing CV: 10818478.pdf
# Processing CV: 11174187.pdf
# Processing CV: 11188218.pdf
# Processing CV: 11773767.pdf
# Processing CV: 11963737.pdf
# Processing CV: 12171093.pdf
# Processing CV: 12544735.pdf
# Processing CV: 13072354.pdf
# Processing CV: 13115648.pdf
# Processing CV: 13342150.pdf
# Processing CV: 13593241.pdf
# Processing CV: 13809698.pdf
# Processing CV: 13909762.pdf
# Processing CV: 13967854.pdf
# Processing CV: 14064815.pdf
# Processing CV: 14146106.pdf
# Processing CV: 14176254.pdf
# Processing category: AGRICULTURE
# Processing CV: 10953078.pdf
# Processing CV: 11197262.pdf
# Processing CV: 11676151.pdf
# Processing CV: 11813872.pdf
# Processing CV: 12341902.pdf
# Processing CV: 12674256.pdf
# Processing CV: 14140903.pdf
# Processing CV: 15053703.pdf
# Processing CV: 15546686.pdf
# Processing CV: 15603319.pdf
# Processing CV: 16172429.pdf
# Processing CV: 16507693.pdf
# Processing CV: 16653657.pdf
# Processing CV: 16661264.pdf
# Processing CV: 16849128.pdf
# Processing CV: 17312146.pdf
# Processing CV: 17499196.pdf
# Processing CV: 17640785.pdf
# Processing CV: 18242317.pdf
# Processing CV: 18264694.pdf
# Processing category: APPAREL
# Processing CV: 10182582.pdf
# Processing CV: 10562768.pdf
# Processing CV: 10738095.pdf
# Processing CV: 10876132.pdf
# Processing CV: 11232471.pdf
# Processing CV: 11409460.pdf
# Processing CV: 11677077.pdf
# Processing CV: 12059610.pdf
# Processing CV: 12122372.pdf
# Processing CV: 12668625.pdf
# Processing CV: 12669075.pdf
# Processing CV: 12860543.pdf
# Processing CV: 13386301.pdf
# Processing CV: 13418452.pdf
# Processing CV: 13764840.pdf
# Processing CV: 13807808.pdf
# Processing CV: 13858219.pdf
# Processing CV: 14304010.pdf
# Processing CV: 14413257.pdf
# Processing CV: 14698557.pdf
# Processing category: ARTS
# Processing CV: 10830646.pdf
# Processing CV: 11187796.pdf
# Processing CV: 11360471.pdf
# Processing CV: 11555549.pdf
# Processing CV: 11995013.pdf
# Processing CV: 12334650.pdf
# Processing CV: 12386670.pdf
# Processing CV: 12413512.pdf
# Processing CV: 12777487.pdf
# Processing CV: 13272204.pdf
# Processing CV: 14150896.pdf
# Processing CV: 14248724.pdf
# Processing CV: 14879257.pdf
# Processing CV: 15265464.pdf
# Processing CV: 15306049.pdf
# Processing CV: 16244633.pdf
# Processing CV: 16887936.pdf
# Processing CV: 16962067.pdf
# Processing CV: 17033567.pdf
# Processing CV: 17325147.pdf
# Processing category: AUTOMOBILE
# Processing CV: 11152490.pdf
# Processing CV: 11257723.pdf
# Processing CV: 11797122.pdf
# Processing CV: 11887930.pdf
# Processing CV: 14455622.pdf
# Processing CV: 14508237.pdf
# Processing CV: 15100547.pdf
# Processing CV: 15210069.pdf
# Processing CV: 15484011.pdf
# Processing CV: 15790602.pdf
# Processing CV: 16332293.pdf
# Processing CV: 17510973.pdf
# Processing CV: 17571262.pdf
# Processing CV: 18448085.pdf
# Processing CV: 18932512.pdf
# Processing CV: 22452756.pdf
# Processing CV: 22732234.pdf
# Processing CV: 22946204.pdf
# Processing CV: 23009962.pdf
# Processing CV: 23522150.pdf
# Processing category: AVIATION
# Processing CV: 10176815.pdf
# Processing CV: 10189110.pdf
# Processing CV: 10395944.pdf
# Processing CV: 10567764.pdf
# Processing CV: 10945968.pdf
# Processing CV: 11137306.pdf
# Processing CV: 11169163.pdf
# Processing CV: 11333001.pdf
# Processing CV: 11614114.pdf
# Processing CV: 11752500.pdf
# Processing CV: 11804712.pdf
# Processing CV: 11959428.pdf
# Processing CV: 12043694.pdf
# Processing CV: 12144825.pdf
# Processing CV: 12192507.pdf
# Processing CV: 12239749.pdf
# Processing CV: 12504278.pdf
# Processing CV: 12904972.pdf
# Processing CV: 13195436.pdf
# Processing CV: 13234267.pdf
# Processing category: BANKING
# Processing CV: 10329506.pdf
# Processing CV: 10909673.pdf
# Processing CV: 11065180.pdf
# Processing CV: 11262933.pdf
# Processing CV: 11266906.pdf
# Processing CV: 11637468.pdf
# Processing CV: 11672279.pdf
# Processing CV: 11773925.pdf
# Processing CV: 11842348.pdf
# Processing CV: 12021752.pdf
# Processing CV: 13173522.pdf
# Processing CV: 13393401.pdf
# Processing CV: 13982572.pdf
# Processing CV: 14391434.pdf
# Processing CV: 14626780.pdf
# Processing CV: 15553584.pdf
# Processing CV: 15856762.pdf
# Processing CV: 16300459.pdf
# Processing CV: 16407619.pdf
# Processing CV: 17131084.pdf
# Processing category: BPO
# Processing CV: 11183737.pdf
# Processing CV: 13964744.pdf
# Processing CV: 15145575.pdf
# Processing CV: 15573418.pdf
# Processing CV: 16492045.pdf
# Processing CV: 18589927.pdf
# Processing CV: 19362586.pdf
# Processing CV: 23933031.pdf
# Processing CV: 24727739.pdf
# Processing CV: 26829350.pdf
# Processing CV: 27710853.pdf
# Processing CV: 30709029.pdf
# Processing CV: 31064969.pdf
# Processing CV: 38707449.pdf
# Processing CV: 41152404.pdf
# Processing CV: 45077654.pdf
# Processing CV: 57706851.pdf
# Processing CV: 63158213.pdf
# Processing CV: 69097572.pdf
# Processing CV: 79261033.pdf
# Processing category: BUSINESS-DEVELOPMENT
# Processing CV: 10228751.pdf
# Processing CV: 10235211.pdf
# Processing CV: 10289113.pdf
# Processing CV: 10501991.pdf
# Processing CV: 10541358.pdf
# Processing CV: 10704573.pdf
# Processing CV: 11088337.pdf
# Processing CV: 11289482.pdf
# Processing CV: 11551946.pdf
# Processing CV: 12059198.pdf
# Processing CV: 12230301.pdf
# Processing CV: 12377803.pdf
# Processing CV: 12546838.pdf
# Processing CV: 12632728.pdf
# Processing CV: 12814706.pdf
# Processing CV: 13080868.pdf
# Processing CV: 13199813.pdf
# Processing CV: 13574264.pdf
# Processing CV: 13888506.pdf
# Processing CV: 14055971.pdf
# Processing category: CHEF
# Processing CV: 10001727.pdf
# Processing CV: 10276858.pdf
# Processing CV: 10333299.pdf
# Processing CV: 10588874.pdf
# Processing CV: 10653119.pdf
# Processing CV: 10889157.pdf
# Processing CV: 11121498.pdf
# Processing CV: 11209758.pdf
# Processing CV: 11432686.pdf
# Processing CV: 11444536.pdf
# Processing CV: 12155206.pdf
# Processing CV: 12254068.pdf
# Processing CV: 12420359.pdf
# Processing CV: 12717345.pdf
# Processing CV: 13095891.pdf
# Processing CV: 13212436.pdf
# Processing CV: 13264154.pdf
# Processing CV: 13411858.pdf
# Processing CV: 14569498.pdf
# Processing CV: 14663897.pdf
# Processing category: CONSTRUCTION
# Processing CV: 10041713.pdf
# Processing CV: 10100240.pdf
# Processing CV: 10149490.pdf
# Processing CV: 10176013.pdf
# Processing CV: 10281555.pdf
# Processing CV: 10734870.pdf
# Processing CV: 10820510.pdf
# Processing CV: 11393213.pdf
# Processing CV: 11650031.pdf
# Processing CV: 12212468.pdf
# Processing CV: 12491898.pdf
# Processing CV: 12654876.pdf
# Processing CV: 12666174.pdf
# Processing CV: 12693146.pdf
# Processing CV: 12695537.pdf
# Processing CV: 12826414.pdf
# Processing CV: 12839152.pdf
# Processing CV: 12890045.pdf
# Processing CV: 13907230.pdf
# Processing CV: 14585273.pdf
# Processing category: CONSULTANT
# Processing CV: 10332998.pdf
# Processing CV: 10984392.pdf
# Processing CV: 11020140.pdf
# Processing CV: 11333660.pdf
# Processing CV: 11415967.pdf
# Processing CV: 11835339.pdf
# Processing CV: 12251115.pdf
# Processing CV: 12374933.pdf
# Processing CV: 12526702.pdf
# Processing CV: 12897903.pdf
# Processing CV: 12955994.pdf
# Processing CV: 13215696.pdf
# Processing CV: 13313917.pdf
# Processing CV: 13454871.pdf
# Processing CV: 13569152.pdf
# Processing CV: 13586069.pdf
# Processing CV: 14346702.pdf
# Processing CV: 14517953.pdf
# Processing CV: 14593060.pdf
# Processing CV: 15083600.pdf
# Processing category: DESIGNER
# Processing CV: 10466583.pdf
# Processing CV: 10748989.pdf
# Processing CV: 10751444.pdf
# Processing CV: 11155153.pdf
# Processing CV: 11722421.pdf
# Processing CV: 11807040.pdf
# Processing CV: 11919526.pdf
# Processing CV: 11958994.pdf
# Processing CV: 12415691.pdf
# Processing CV: 12547982.pdf
# Processing CV: 12674307.pdf
# Processing CV: 13014900.pdf
# Processing CV: 13518263.pdf
# Processing CV: 13557622.pdf
# Processing CV: 13774329.pdf
# Processing CV: 13998435.pdf
# Processing CV: 14014749.pdf
# Processing CV: 14528265.pdf
# Processing CV: 14724186.pdf
# Processing CV: 14743911.pdf
# Processing category: DIGITAL-MEDIA
# Processing CV: 10005171.pdf
# Processing CV: 10515955.pdf
# Processing CV: 11005406.pdf
# Processing CV: 11270462.pdf
# Processing CV: 11677012.pdf
# Processing CV: 12085736.pdf
# Processing CV: 13328680.pdf
# Processing CV: 13343786.pdf
# Processing CV: 13503650.pdf
# Processing CV: 13837784.pdf
# Processing CV: 14036515.pdf
# Processing CV: 14209965.pdf
# Processing CV: 14556869.pdf
# Processing CV: 14761906.pdf
# Processing CV: 14771530.pdf
# Processing CV: 14945250.pdf
# Processing CV: 15226699.pdf
# Processing CV: 15353911.pdf
# Processing CV: 15484097.pdf
# Processing CV: 16276121.pdf
# Processing category: ENGINEERING
# Processing CV: 10030015.pdf
# Processing CV: 10219099.pdf
# Processing CV: 10624813.pdf
# Processing CV: 10712803.pdf
# Processing CV: 10985403.pdf
# Processing CV: 11890896.pdf
# Processing CV: 11981094.pdf
# Processing CV: 12011623.pdf
# Processing CV: 12022566.pdf
# Processing CV: 12472574.pdf
# Processing CV: 12488356.pdf
# Processing CV: 12518008.pdf
# Processing CV: 12748557.pdf
# Processing CV: 13149176.pdf
# Processing CV: 13264796.pdf
# Processing CV: 14049846.pdf
# Processing CV: 14206561.pdf
# Processing CV: 14554542.pdf
# Processing CV: 15139979.pdf
# Processing CV: 15601399.pdf
# Processing category: FINANCE
# Processing CV: 10549585.pdf
# Processing CV: 11441764.pdf
# Processing CV: 11490673.pdf
# Processing CV: 11877150.pdf
# Processing CV: 12071138.pdf
# Processing CV: 12858898.pdf
# Processing CV: 14106638.pdf
# Processing CV: 14181049.pdf
# Processing CV: 14408510.pdf
# Processing CV: 14413148.pdf
# Processing CV: 14722634.pdf
# Processing CV: 15011085.pdf
# Processing CV: 15224503.pdf
# Processing CV: 15717923.pdf
# Processing CV: 15792052.pdf
# Processing CV: 15891494.pdf
# Processing CV: 16426777.pdf
# Processing CV: 16449850.pdf
# Processing CV: 17392859.pdf
# Processing CV: 17775916.pdf
# Processing category: FITNESS
# Processing CV: 10235429.pdf
# Processing CV: 10268614.pdf
# Processing CV: 10333051.pdf
# Processing CV: 10428916.pdf
# Processing CV: 10568350.pdf
# Processing CV: 10816645.pdf
# Processing CV: 10969918.pdf
# Processing CV: 11130200.pdf
# Processing CV: 11332602.pdf
# Processing CV: 11522068.pdf
# Processing CV: 12019284.pdf
# Processing CV: 12092347.pdf
# Processing CV: 12695799.pdf
# Processing CV: 12791244.pdf
# Processing CV: 12923795.pdf
# Processing CV: 12938389.pdf
# Processing CV: 13037145.pdf
# Processing CV: 13367322.pdf
# Processing CV: 13675377.pdf
# Processing CV: 14107571.pdf
# Processing category: HEALTHCARE
# Processing CV: 10062724.pdf
# Processing CV: 10076271.pdf
# Processing CV: 10251432.pdf
# Processing CV: 10466208.pdf
# Processing CV: 10480456.pdf
# Processing CV: 10568183.pdf
# Processing CV: 11378657.pdf
# Processing CV: 11605833.pdf
# Processing CV: 11653906.pdf
# Processing CV: 11704150.pdf
# Processing CV: 12315079.pdf
# Processing CV: 12333703.pdf
# Processing CV: 12613221.pdf
# Processing CV: 12938200.pdf
# Processing CV: 13352113.pdf
# Processing CV: 13565152.pdf
# Processing CV: 13575312.pdf
# Processing CV: 14062078.pdf
# Processing CV: 14667957.pdf
# Processing CV: 15499825.pdf
# Processing category: HR
# Processing CV: 10399912.pdf
# Processing CV: 10694288.pdf
# Processing CV: 11480899.pdf
# Processing CV: 11592605.pdf
# Processing CV: 11698189.pdf
# Processing CV: 11763983.pdf
# Processing CV: 11847784.pdf
# Processing CV: 12786012.pdf
# Processing CV: 13376919.pdf
# Processing CV: 13520837.pdf
# Processing CV: 13879043.pdf
# Processing CV: 14225422.pdf
# Processing CV: 14256329.pdf
# Processing CV: 14640322.pdf
# Processing CV: 14886205.pdf
# Processing CV: 15041689.pdf
# Processing CV: 15375009.pdf
# Processing CV: 15575117.pdf
# Processing CV: 15576950.pdf
# Processing CV: 16852973.pdf
# Processing category: INFORMATION-TECHNOLOGY
# Processing CV: 10089434.pdf
# Processing CV: 10247517.pdf
# Processing CV: 10265057.pdf
# Processing CV: 10553553.pdf
# Processing CV: 10641230.pdf
# Processing CV: 10839851.pdf
# Processing CV: 10840430.pdf
# Processing CV: 11580408.pdf
# Processing CV: 11584809.pdf
# Processing CV: 11957080.pdf
# Processing CV: 12045067.pdf
# Processing CV: 12334140.pdf
# Processing CV: 12635195.pdf
# Processing CV: 12763627.pdf
# Processing CV: 13385306.pdf
# Processing CV: 13405733.pdf
# Processing CV: 13477922.pdf
# Processing CV: 13836471.pdf
# Processing CV: 14789139.pdf
# Processing CV: 15118506.pdf
# Processing category: PUBLIC-RELATIONS
# Processing CV: 10070224.pdf
# Processing CV: 10554045.pdf
# Processing CV: 10873344.pdf
# Processing CV: 10926726.pdf
# Processing CV: 11160414.pdf
# Processing CV: 11624880.pdf
# Processing CV: 11635137.pdf
# Processing CV: 11842274.pdf
# Processing CV: 11850315.pdf
# Processing CV: 11902276.pdf
# Processing CV: 12191094.pdf
# Processing CV: 12237267.pdf
# Processing CV: 12545844.pdf
# Processing CV: 12567516.pdf
# Processing CV: 12920612.pdf
# Processing CV: 13129275.pdf
# Processing CV: 13727873.pdf
# Processing CV: 13915715.pdf
# Processing CV: 14009087.pdf
# Processing CV: 14128006.pdf
# Processing category: SALES
# Processing CV: 10138632.pdf
# Processing CV: 10464113.pdf
# Processing CV: 10603337.pdf
# Processing CV: 10724818.pdf
# Processing CV: 10898339.pdf
# Processing CV: 12082377.pdf
# Processing CV: 12351749.pdf
# Processing CV: 12696104.pdf
# Processing CV: 12820557.pdf
# Processing CV: 13178604.pdf
# Processing CV: 13348915.pdf
# Processing CV: 13637605.pdf
# Processing CV: 13812481.pdf
# Processing CV: 14267489.pdf
# Processing CV: 14358578.pdf
# Processing CV: 14381464.pdf
# Processing CV: 15273850.pdf
# Processing CV: 15581242.pdf
# Processing CV: 15620421.pdf
# Processing CV: 15765660.pdf
# Processing category: TEACHER
# Processing CV: 10504237.pdf
# Processing CV: 10527994.pdf
# Processing CV: 10909720.pdf
# Processing CV: 11336022.pdf
# Processing CV: 11616482.pdf
# Processing CV: 11943065.pdf
# Processing CV: 12467531.pdf
# Processing CV: 12587973.pdf
# Processing CV: 13087952.pdf
# Processing CV: 13296856.pdf
# Processing CV: 13330982.pdf
# Processing CV: 13583538.pdf
# Processing CV: 13855004.pdf
# Processing CV: 14958913.pdf
# Processing CV: 15850434.pdf
# Processing CV: 15899269.pdf
# Processing CV: 16210888.pdf
# Processing CV: 16270906.pdf
# Processing CV: 16820422.pdf
# Processing CV: 17311685.pdf

# %%
import sqlite3

def verify_database(db_file='atsdatabase.db'):
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    print("\n--- Applicants ---")
    cursor.execute('SELECT * FROM applicantprofile')
    applicants = cursor.fetchall()
    for applicant in applicants:
        print(applicant)

    print("\n--- Applications ---")
    cursor.execute('SELECT * FROM applicationdetail')
    applications = cursor.fetchall()
    for application in applications:
        print(application)

    conn.close()

verify_database()
# Out:
# --- Applicants ---
# (1, 'Sara', 'Smith', '1969-01-03', '949 Burton Shoal Suite 385, East Luke, RI 27904', '+1-500-967-7053x41466')
# (2, 'Katie', 'Saepuloh', '1973-12-18', 'USNS Howard, FPO AP 43056', '8405878720')
# (3, 'Chris', 'Hernandez', '1992-07-20', '83813 Anthony Plains, West Maria, MS 16793', '892-877-9096')
# (4, 'Supri', 'Smith', '1970-09-08', 'PSC 4251, Box 0974, APO AE 16678', '450-219-6785x348')
# (5, 'David', 'Davis', '1997-03-28', '813 Obrien Overpass Apt. 811, North Amanda, ID 19969', '456-648-0716')
# (6, 'Sara', 'Suherman', '1966-10-22', '147 Nathan Hollow, Jessicaberg, MO 43245', '534.949.9678x951')
# (7, 'Asep', 'Garcia', '2001-10-08', 'Unit 9958 Box 1848, DPO AA 32609', '001-483-659-1612')
# (8, 'Michael', 'Williams', '1975-11-30', '88303 Clark Overpass Apt. 488, Yangberg, DE 99344', '255.360.6414')
# (9, 'Sara', 'Martinez', '1978-05-19', '67953 Frank Squares, West George, PA 98747', '+1-344-715-9348x80972')
# (10, 'Emily', 'Sumarna', '1983-02-18', '6138 Aimee Lane Suite 656, Tiffanyfort, GA 84414', '627.717.8906x8487')
# (11, 'Jajang', 'Davis', '1992-12-15', '7400 Mccarthy Groves Suite 780, South Jamestown, KS 70191', '(844)425-3229x70156')
# (12, 'Alex', 'Williams', '1975-09-03', '715 Kimberly Corners, Johnsonfort, MS 83861', '615.695.4293')
# (13, 'Asep', 'Jones', '1996-08-24', '907 Shawn Ville, South Jeffery, VT 49094', '6268025639')
# (14, 'John', 'Johnson', '1971-06-09', 'Unit 6742 Box 5475, DPO AP 31366', '8325240800')
# (15, 'Supri', 'Santosa', '1990-05-21', '10148 Juan Manor Suite 992, Port Victoriaville, GA 94799', '001-644-876-1244x559')
# (16, 'David', 'Smith', '1989-07-28', '67570 Franklin Hills, Codyfurt, CO 61802', '820.878.3995x463')
# (17, 'Emily', 'Williams', '1993-11-28', '447 David Stravenue, Julieburgh, OK 66373', '8279747807')
# (18, 'Jajang', 'Miller', '1982-07-25', '18820 Smith Pike Suite 557, Garzafurt, WI 76875', '001-515-633-3676')
# (19, 'Alex', 'Martinez', '1971-12-28', 'USS Sosa, FPO AA 63163', '(419)488-6362')
# (20, 'David', 'Hernandez', '1976-05-14', '3080 Maria Burg, Margaretburgh, ID 79614', '+1-569-356-1326')
# (21, 'Cecep', 'Miller', '1983-10-09', '56849 Mccoy Route, Phillipport, NC 07537', '001-463-546-0051x160')
# (22, 'Katie', 'Davis', '1989-05-14', '5091 Robert Viaduct, Lake Lorettatown, CT 01198', '670.481.0029')
# (23, 'Jane', 'Martinez', '1967-10-18', 'PSC 9584, Box 9559, APO AP 87776', '382-469-2904')
# (24, 'Alex', 'Brown', '2006-01-31', '8866 Christopher Spring Suite 664, East Davidville, AR 22288', '(556)808-9160x8784')
# (25, 'Jajang', 'Johnson', '1984-08-03', '7394 Gray Meadows, North Jennifertown, AZ 84862', '001-907-533-3670x149')
# (26, 'Laura', 'Santosa', '1989-05-31', '31390 Donald Lakes Apt. 365, South Jeremy, FL 60137', '(749)554-5395x3121')
# (27, 'Alex', 'Santosa', '1989-11-30', '980 Mack View, New Anitachester, OH 98801', '941.414.3279')
# (28, 'Cecep', 'Martinez', '1989-03-01', '511 Laura Pass Suite 717, North Darleneport, SD 33470', '757.415.3548x49098')
# (29, 'David', 'Garcia', '1983-12-27', '6152 Alyssa Fort Suite 487, South Kaylee, IA 55925', '+1-937-633-7584x3476')
# (30, 'Katie', 'Garcia', '1990-08-29', '592 Lee Square Apt. 603, South Michellestad, RI 43206', '649.813.2254')
# (31, 'Laura', 'Miller', '2006-07-06', 'Unit 6585 Box 4531, DPO AA 41298', '+1-488-727-5831x619')
# (32, 'Alex', 'Suherman', '1978-08-05', '8948 Hodge Drive, Littleton, UT 41953', '4348380792')
# (33, 'Asep', 'Santosa', '1974-08-26', '05072 Jennifer Fort, Lake Beverlyburgh, ME 29730', '625.755.8100x2532')
# (34, 'Michael', 'Smith', '1968-09-22', '97781 Daniel Drive, East Candace, AL 70793', '001-686-406-7174')
# (35, 'Jane', 'Santosa', '1985-07-23', '70727 English Fields Apt. 911, Smithbury, AZ 69481', '+1-689-809-5013x76817')
# (36, 'Laura', 'Sumarna', '1999-06-08', '05498 Gray Brooks, Leeview, LA 60615', '(628)509-6285')
# (37, 'Dadang', 'Garcia', '1985-03-26', 'USCGC Bean, FPO AP 31367', '519.846.0479')
# (38, 'Dadang', 'Saepuloh', '1998-07-20', '8295 Ashley Stream Suite 572, Turnerview, NY 80069', '(553)282-7751x82429')
# (39, 'Laura', 'Garcia', '1975-02-14', '946 Mcgrath Neck, Brownmouth, PA 87246', '(989)254-9314x0239')
# (40, 'Supri', 'Jones', '1971-10-11', 'Unit 2518 Box 3679, DPO AP 28321', '001-706-296-4016')
# (41, 'Jane', 'Garcia', '1979-05-26', '33438 Cuevas Crescent, East Ashleymouth, IN 96208', '001-680-742-7074x6785')
# (42, 'Jane', 'Johnson', '1990-12-07', '547 Brandy Meadow, Robertsberg, NY 38668', '(323)382-0566x79313')
# (43, 'Dadang', 'Martinez', '1984-04-16', '1863 Michael Landing, South Jesseview, IL 79419', '372-874-7157x7442')
# (44, 'Jane', 'Saepuloh', '1979-07-12', '2766 Small Courts Suite 327, Patriciaside, NC 74776', '001-379-419-0282x6117')
# (45, 'Jajang', 'Brown', '1990-03-24', '7113 Russell Spring, New Victoriaborough, AZ 52564', '463-365-1549')
# (46, 'Sara', 'Brown', '1971-07-25', '49458 Thomas Ford, Shellyhaven, MH 98307', '436-958-2257x3541')
# (47, 'Jane', 'Brown', '1984-01-15', '97203 Zimmerman Drive, New Nathaniel, CT 08657', '(771)722-1331')
# (48, 'Michael', 'Santosa', '1975-03-09', '437 Hoover Land Apt. 412, Lake Clintonmouth, TN 36367', '+1-521-997-8558x2203')
# (49, 'Dadang', 'Smith', '1978-05-05', '0397 Thornton Ways Apt. 526, Jarvishaven, MI 20181', '821.986.2715x5111')
# (50, 'Cecep', 'Smith', '1965-12-13', '70893 Christopher Circles, Sandovaltown, LA 20644', '001-214-604-0436x920')
# (51, 'Alex', 'Garcia', '1970-09-14', '1039 Reyes Green Apt. 026, Williamsmouth, KS 56104', '+1-571-932-6640x837')
# (52, 'Supri', 'Williams', '1998-10-02', '91931 Benjamin Trafficway, New Miguel, FM 52707', '001-269-548-5189x1848')
# (53, 'Chris', 'Sumarna', '1968-09-19', '48119 Parker Lights Suite 638, West Timothy, TX 27370', '908-427-9974x603')
# (54, 'John', 'Santosa', '2005-02-02', '0526 Clark Groves Suite 659, North Stephen, FL 62885', '9839463719')
# (55, 'Chris', 'Santosa', '1994-02-18', '89601 Daniel Island Apt. 094, West Peter, ME 13360', '818.635.2990')
# (56, 'David', 'Saepuloh', '2006-12-01', '2204 Walters Garden, Medinaland, FL 45156', '499.496.9981')
# (57, 'John', 'Hernandez', '2000-07-14', '1235 Debbie Lakes, South Kellyberg, WA 64174', '+1-836-953-1488')
# (58, 'Emily', 'Hernandez', '1997-09-20', '74729 Wong Road, Port Katrina, ID 64574', '991-915-0504x3491')
# (59, 'Cecep', 'Santosa', '2004-07-11', '49910 Sanders Isle, Boyerfurt, WI 60517', '789.251.6482x8925')
# (60, 'John', 'Martinez', '2000-04-08', '807 Taylor Place Apt. 784, West Samanthatown, KS 51479', '298.840.1497')
# (61, 'Asep', 'Miller', '1976-05-14', '54381 Payne Stream, Lake Heatherchester, WY 44659', '+1-951-888-2021x705')
# (62, 'Emily', 'Suherman', '1986-09-17', '5247 Patricia Ridges Apt. 956, Jerryshire, AL 94395', '+1-888-589-4706x795')
# (63, 'Cecep', 'Hernandez', '2001-03-31', 'Unit 2401 Box 8142, DPO AP 17775', '476-951-1242x896')
# (64, 'John', 'Saepuloh', '2004-07-02', '87624 Berry Gateway Apt. 130, Meganland, GA 63881', '001-934-972-4562x730')
# (65, 'Sara', 'Sumarna', '1968-08-15', '757 Savage Garden, Mclaughlinland, FM 32368', '746-279-6384x541')
# (66, 'Asep', 'Martinez', '1991-04-10', '40085 Gallegos Junction, Nguyenburgh, OR 57351', '7305591032')
# (67, 'John', 'Smith', '1970-11-02', '3714 Ford Neck, Cuevaschester, SC 91852', '453-322-2102x165')
# (68, 'Dadang', 'Jones', '1990-10-01', '911 Eric Causeway, Port Karenland, CT 97471', '309.715.1933')
# (69, 'Supri', 'Garcia', '1968-07-23', '70531 Eric Isle Suite 566, North Natashaview, DE 77809', '(470)771-4833x69861')
# (70, 'Cecep', 'Johnson', '1975-04-30', '05418 Gonzales Street, North Lesliefurt, RI 92456', '707.792.5790')
# (71, 'Alex', 'Sumarna', '1966-06-25', '352 Garcia Square Apt. 120, South Christy, NY 52637', '+1-603-903-2772x84365')
# (72, 'Asep', 'Williams', '1994-10-12', '998 Rojas Shores, Mcdonaldfurt, MN 03883', '693-664-7576')
# (73, 'Jane', 'Davis', '1974-06-02', '44364 Todd Mountain, Maryfurt, IL 66546', '001-883-530-8110x8858')
# (74, 'Jajang', 'Santosa', '1997-07-09', '964 Walters Dam Suite 391, East Leahside, TX 26787', '+1-700-344-8924x2436')
# (75, 'David', 'Sumarna', '1988-12-23', 'USNS Gross, FPO AA 59956', '616-635-9230x8765')
# (76, 'John', 'Garcia', '2003-11-08', '026 Jeffery Well, West Daniellefurt, WV 26055', '788.314.3438x531')
# (77, 'Alex', 'Jones', '2004-09-06', '51028 Gregory Field Suite 826, Tamaraborough, PR 72017', '359.792.4682')
# (78, 'Supri', 'Davis', '1990-09-08', '4330 Nguyen Mews, East Mary, MT 23046', '(541)845-3689')
# (79, 'Emily', 'Johnson', '1988-11-24', '991 Miller Underpass, Mercedesmouth, IN 29533', '001-924-725-9145x25095')
# (80, 'Michael', 'Martinez', '2000-04-07', '0266 Stevens Junction Apt. 607, Davidfurt, MT 75456', '001-217-650-0582')
# (81, 'Jajang', 'Martinez', '1997-01-21', '5648 Shawn Manors Suite 336, Jessicaton, OK 50823', '001-979-230-7003')
# (82, 'Dadang', 'Brown', '1996-08-09', '9175 Nicole Meadows, New Sharon, VT 47242', '223.770.7319')
# (83, 'Supri', 'Hernandez', '1972-04-22', '0827 Short Way Apt. 570, Friedmanchester, NY 74384', '(326)294-2746x4020')
# (84, 'Asep', 'Johnson', '1998-05-05', '786 Maria Tunnel, Weeksborough, IL 22320', '+1-727-375-3328x740')
# (85, 'Michael', 'Suherman', '1976-08-05', '7287 Wilson Haven, West Jenniferhaven, NM 81228', '796-501-0435')
# (86, 'Dadang', 'Williams', '1977-09-27', '88398 Flowers Harbor Apt. 961, Aaronside, FL 68602', '(996)857-0767x678')
# (87, 'Chris', 'Garcia', '1973-04-15', 'USS Berry, FPO AE 13082', '5966204155')
# (88, 'Sara', 'Saepuloh', '1982-03-07', '422 Jennifer Pines, Lake Morganview, OH 58801', '+1-753-555-1320x63333')
# (89, 'Michael', 'Davis', '2002-11-06', '8092 Michael Via, South Brittneybury, FL 46768', '214-282-1549')
# (90, 'Asep', 'Hernandez', '1995-08-07', '1999 Ellison Lakes, New Randy, GA 96946', '001-364-403-0773x806')
# (91, 'Chris', 'Martinez', '2003-10-09', '803 Mullins Gardens, Lisamouth, ME 67264', '001-882-503-0242x069')
# (92, 'Emily', 'Davis', '1966-12-28', '83286 Brown Parkways, Port Belindabury, OR 35518', '573.782.1275')
# (93, 'Laura', 'Hernandez', '2001-12-18', '5877 Brittney Plains Apt. 935, Reynoldsville, NC 93156', '580-967-5327')
# (94, 'Michael', 'Sumarna', '1985-05-01', '10683 Paul Key Apt. 109, Howardside, VI 66272', '001-759-995-4809x16299')
# (95, 'Alex', 'Smith', '1980-03-10', '3171 Benjamin Viaduct, Elijahhaven, VI 32127', '738-495-7227x93397')
# (96, 'Cecep', 'Jones', '1999-03-10', '418 Mills Brook Suite 155, Patrickview, MT 71804', '001-511-488-5920x1992')
# (97, 'Dadang', 'Davis', '1988-02-07', '384 Fuller Prairie, Port Sergio, MH 78716', '(888)983-4115x37730')
# (98, 'Cecep', 'Williams', '1993-10-19', '743 Arnold Corner, West Kathryntown, MS 42585', '001-242-728-1835x700')
# (99, 'Laura', 'Saepuloh', '2004-04-13', '9246 Espinoza Harbor Apt. 859, Christopherside, MN 38771', '202.657.3401')
# (100, 'Sara', 'Johnson', '1996-07-04', '791 Kelly Plain Apt. 477, West Mary, ND 33371', '668.838.1029x45074')
# (101, 'Michael', 'Saepuloh', '2001-05-18', '930 Tina Knolls Apt. 390, East Meaganbury, GU 36307', '+1-794-335-1192')
# (102, 'Jajang', 'Hernandez', '2006-02-16', '09055 Smith Way, Troychester, NY 94696', '(400)260-3099x0645')
# (103, 'Jane', 'Smith', '2005-11-20', '447 James Club, East Denise, NE 22030', '(302)724-4406')
# (104, 'Katie', 'Williams', '1977-11-24', '771 Martinez Shoals, Patriciaside, KY 22043', '+1-463-975-6228')
# (105, 'Michael', 'Johnson', '1968-07-18', '9516 Woods Branch, Priceton, VA 01524', '9048286447')
# (106, 'Cecep', 'Saepuloh', '1968-12-18', '382 Zavala Road, Paulfort, OK 84776', '306-241-5770x711')
# (107, 'David', 'Williams', '1974-11-15', '200 Kathleen Lakes Suite 590, New Dustin, IA 16987', '(970)478-9541x6979')
# (108, 'David', 'Jones', '2001-06-01', 'PSC 6857, Box 0315, APO AP 86417', '(913)582-9915x103')
# (109, 'Katie', 'Jones', '1997-03-05', '0619 Hannah Parks, Joshualand, VT 35035', '001-200-781-5868x9888')
# (110, 'Cecep', 'Brown', '1969-05-28', '978 Goodman Trail Apt. 905, West Loritown, MS 66256', '001-622-944-4179')
# (111, 'Jajang', 'Suherman', '1971-03-11', '092 Elizabeth Mountains, Rodriguezburgh, MO 37153', '738.406.9219')
# (112, 'Dadang', 'Sumarna', '1969-06-23', '18511 Gina Motorway, Jacksonshire, GA 93625', '574-646-4495x590')
# (113, 'Chris', 'Suherman', '1965-11-05', '101 Gould Orchard, New Benjaminport, OK 44202', '+1-350-852-5402x624')
# (114, 'Jajang', 'Saepuloh', '1973-04-01', '0584 Solis Orchard Apt. 825, Buckleychester, AR 80150', '001-734-487-8955x078')
# (115, 'Katie', 'Johnson', '1970-02-06', '81416 Gross Roads Apt. 365, Andrewport, HI 72103', '001-364-245-9576')
# (116, 'Chris', 'Smith', '1965-01-27', '072 Oneill Lane, Ashleyberg, TX 65950', '(772)848-7265')
# (117, 'David', 'Brown', '1966-01-25', '91531 Stewart Knoll Apt. 763, Adamshaven, HI 35603', '(549)811-7218x69004')
# (118, 'Chris', 'Johnson', '2002-12-29', '22203 Ford Center, Jacksonbury, CA 54489', '001-792-431-5843x9666')
# (119, 'Laura', 'Smith', '1975-01-12', '12635 Tina Wall Suite 418, West Davidmouth, AK 71996', '001-639-717-8957')
# (120, 'John', 'Sumarna', '1981-08-14', '63810 Peterson Lights Apt. 423, New Nicholasfort, NV 17102', '001-983-482-7702x4083')
# (121, 'Asep', 'Brown', '1993-05-10', '2748 Jenna Skyway, Lake Jason, MD 77450', '534.522.4723x6452')
# (122, 'Katie', 'Hernandez', '1979-08-19', '070 Christina Road Suite 751, Hortonborough, HI 06448', '462.707.3718x65442')
# (123, 'John', 'Williams', '1996-10-29', '12602 Alexander Pass Suite 362, New Mark, UT 90610', '001-282-276-6757x33963')
# (124, 'Jane', 'Jones', '1980-10-31', '01425 George Field Apt. 285, Kaitlynland, ID 76299', '001-714-389-7964x773')
# (125, 'Sara', 'Jones', '1974-09-24', '200 Samantha Views Apt. 708, Bowmanmouth, ID 81590', '001-994-739-9663x14740')
# (126, 'Emily', 'Miller', '1995-04-10', '8430 Cindy Unions Apt. 893, New Russellborough, MT 73346', '903.967.5897x2624')
# (127, 'David', 'Suherman', '1999-01-17', '4680 Mitchell Forges Suite 002, Deanbury, NC 46813', '001-316-891-5135x332')
# (128, 'Michael', 'Brown', '1990-03-16', '019 Coleman Manors Apt. 097, Devinton, HI 35145', '(873)475-6106x51008')
# (129, 'Cecep', 'Sumarna', '1980-01-26', '40890 Burns Roads, East Austinshire, MN 31015', '446-868-4329')
# (130, 'Michael', 'Jones', '1976-12-17', '46170 Adam Track Suite 798, West Courtneyport, DC 54844', '(203)692-2538x03817')
# (131, 'Dadang', 'Santosa', '1974-07-09', '118 Edwards Circle, South Johnborough, UT 42067', '001-867-972-5183x332')
# (132, 'Emily', 'Smith', '2007-04-24', 'Unit 4375 Box 5366, DPO AA 38373', '(891)418-9424x9155')
# (133, 'Sara', 'Miller', '1983-09-28', '6017 Valerie Ports, Carolinefort, WV 57806', '697-398-2241')
# (134, 'Sara', 'Hernandez', '1977-02-19', '72774 Rebecca Bridge Apt. 146, Rodneyview, OK 90289', '001-522-424-4919')
# (135, 'Supri', 'Suherman', '2000-03-29', '93663 Graham Shoals Suite 070, Port Michaelberg, WY 76102', '563-273-0703')
# (136, 'Jajang', 'Garcia', '1983-02-19', '3078 Keith Parks Apt. 200, North Staceymouth, AR 53985', '554-235-6950x420')
# (137, 'Emily', 'Brown', '1987-11-17', '5970 Scott Springs, Port Kiara, AR 61876', '682-679-9467x15228')
# (138, 'Emily', 'Garcia', '1977-04-30', '1900 William Lodge Suite 627, Reyesshire, GU 20044', '001-383-724-1642x155')
# (139, 'Laura', 'Williams', '1986-10-21', '93073 Thompson Route Suite 225, North Rhonda, MO 58341', '+1-424-804-7495')
# (140, 'Cecep', 'Suherman', '1980-12-10', '65506 Peterson Rue, Jeremyville, AS 26650', '+1-717-508-6742x9408')
# (141, 'Cecep', 'Davis', '1965-08-18', '394 Kevin Dam, Brendafort, VI 56190', '430.465.5597x7432')
# (142, 'Cecep', 'Garcia', '1987-06-19', '73552 Chase Road, Gregberg, ND 63409', '308-358-9033')
# (143, 'Michael', 'Hernandez', '1970-05-18', '4135 George Villages Apt. 373, Port Joshuamouth, NJ 65066', '637.307.0907')
# (144, 'Alex', 'Miller', '1978-01-02', '82210 Shane Stravenue Suite 291, Zacharyville, WY 58172', '380.317.3279x3929')
# (145, 'Jajang', 'Williams', '2002-05-15', '56261 Johnson Burgs Apt. 014, Lake Nicole, OK 04917', '+1-885-972-8608x31016')
# (146, 'Jane', 'Hernandez', '1977-04-28', '835 Sellers Hollow, Jeffreytown, CO 89815', '223.205.4176x2590')
# (147, 'Dadang', 'Hernandez', '1999-06-22', '6122 House Summit, Arnoldstad, LA 98191', '2676782863')
# (148, 'Alex', 'Hernandez', '2007-05-31', '23579 Bell Hollow Apt. 530, Phillipsstad, OK 45550', '001-947-414-3005x5115')
# (149, 'David', 'Johnson', '2007-05-08', '86452 Cynthia Harbor Apt. 487, Shawfurt, MD 89284', '375-539-2961')
# (150, 'Alex', 'Saepuloh', '1969-12-27', '082 Veronica Glen, Staceyhaven, ID 22933', '391-263-5939')
# (151, 'Supri', 'Sumarna', '1965-04-12', '0003 Lawrence Burgs Suite 875, South Benjaminstad, NM 96696', '+1-965-421-2546x7848')
# (152, 'Sara', 'Garcia', '1984-05-30', '1334 Romero Mountain Apt. 609, Fieldsburgh, WV 68524', '(719)936-6773x894')
# (153, 'John', 'Miller', '1989-04-12', '52925 Whitney Crossing, Port Brendahaven, NE 55388', '+1-935-210-6046x46837')
# (154, 'Alex', 'Davis', '1991-07-08', '90078 Hart Radial Suite 962, Catherinemouth, UT 19091', '766.491.5305')
# (155, 'Emily', 'Saepuloh', '1978-06-27', '3610 Brittany Dam, Hardyshire, VA 84513', '323-690-8205')
# (156, 'John', 'Brown', '2002-11-18', '9139 Rollins Forest Suite 215, Jenniferborough, NV 25474', '001-262-536-7109x21326')
# (157, 'Chris', 'Saepuloh', '2000-07-12', 'PSC 3241, Box 9377, APO AE 10738', '001-356-658-7359x54165')
# (158, 'Jajang', 'Sumarna', '1966-08-15', 'USCGC Scott, FPO AE 07473', '998-999-1152')
# (159, 'Asep', 'Smith', '1978-01-21', '43880 Steven Orchard, Lake Christopher, NM 75586', '752-897-4487x7700')
# (160, 'Supri', 'Brown', '1988-09-20', '86617 Young Extension Suite 702, New Amanda, MP 73152', '531-429-9079')
# (161, 'Chris', 'Davis', '1996-09-02', '4070 Fischer Prairie Apt. 579, Lake Nicholas, PA 56267', '471.563.8819x4099')
# (162, 'John', 'Suherman', '1977-02-02', 'Unit 2227 Box 1572, DPO AA 55430', '645.649.2465x51107')
# (163, 'Asep', 'Saepuloh', '1966-01-31', '55972 Patel Forks Apt. 400, East Monicaberg, OK 66150', '(875)851-9204')
# (164, 'Chris', 'Jones', '1982-02-19', '08100 Dean Underpass, Lake William, NE 12111', '+1-862-896-8840x50204')
# (165, 'Asep', 'Sumarna', '1997-05-23', 'USNV Lane, FPO AA 67223', '(238)251-1250x44919')
# (166, 'Jane', 'Williams', '2000-07-11', '87585 Brian Springs Suite 624, New Shelby, AL 69401', '911.261.5852')
# (167, 'Katie', 'Sumarna', '1985-12-16', '84841 Ward Lakes, Wagnerview, OH 71898', '307-799-6189x06053')
# (168, 'Laura', 'Suherman', '1981-09-07', '54545 Patel Mills Apt. 946, Andersonton, MP 95935', '(502)926-7795x579')
# (169, 'Katie', 'Smith', '1968-05-09', 'Unit 5160 Box 6619, DPO AA 40141', '497-641-6861')
# (170, 'Jajang', 'Smith', '1971-01-19', '861 Paul Radial Suite 924, Ambershire, MN 88030', '(999)461-6478')
# (171, 'Dadang', 'Miller', '1969-11-05', '567 Janet Wall Suite 678, East Gregtown, DC 05229', '3775869517')
# (172, 'Katie', 'Santosa', '1974-02-06', '251 Darren Fall Suite 497, West Joshua, NC 37644', '+1-828-435-3057')
# (173, 'Sara', 'Williams', '2006-09-23', '79669 Solis Isle Suite 069, Rosemouth, ID 70472', '001-723-677-1310x66622')
# (174, 'Jajang', 'Jones', '2001-04-06', '7813 Adam Rest, Holdenville, PW 32889', '(709)518-1910')
# (175, 'David', 'Martinez', '1987-12-14', '450 Johnson Stravenue Apt. 596, North Melissa, MA 40045', '001-879-899-3384x11070')
# (176, 'David', 'Santosa', '2000-02-06', '026 Michael Wall, West Kathy, NJ 11244', '+1-527-851-7596')
# (177, 'Katie', 'Martinez', '1977-10-29', '43658 Lindsey Islands, Isaacland, OR 89463', '3986710526')
# (178, 'Emily', 'Santosa', '1998-08-15', '100 Anna Wall, South Shelly, PW 79698', '001-640-296-4701x042')
# (179, 'Supri', 'Miller', '1967-05-16', '5613 Lucero Place Suite 852, North Lynnland, MN 17994', '4442143833')
# (180, 'Michael', 'Garcia', '1994-08-11', '63645 Lopez Wells Apt. 917, North Stacie, NV 89008', '909-372-4860x41856')
# (181, 'Laura', 'Davis', '1971-11-09', '2353 Christopher Tunnel, Brianchester, DC 60183', '973-726-5245x515')
# (182, 'Emily', 'Jones', '1979-05-19', '8491 Williams Centers Apt. 179, Scottmouth, NV 85312', '+1-971-455-5012x1779')
# (183, 'Laura', 'Johnson', '1971-03-28', '4401 Danny Court Suite 112, South Mark, MP 31584', '(741)510-8024x746')
# (184, 'Katie', 'Suherman', '1975-01-27', '09700 Anderson Road, North Matthewborough, CO 25276', '001-640-868-9814x6028')
# (185, 'Asep', 'Davis', '1968-04-05', '76022 Chad Square Suite 508, New Mary, NC 06089', '+1-449-925-8521')
# (186, 'Supri', 'Martinez', '2003-02-17', '8777 Hoover Keys Suite 584, North Codyburgh, GA 44459', '001-777-282-0301x40832')
# (187, 'Asep', 'Suherman', '1973-11-09', '959 Gary Gardens, North Kevinview, KS 43957', '(657)268-2993x8687')
# (188, 'Dadang', 'Suherman', '1975-05-26', '5825 Ryan Fort, Benjaminfort, NE 29991', '001-998-339-9066x283')
#
# --- Applications ---
# (1, 1, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\10554236.pdf')
# (2, 2, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\10674770.pdf')
# (3, 3, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\11163645.pdf')
# (4, 4, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\11759079.pdf')
# (5, 5, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12065211.pdf')
# (6, 6, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12202337.pdf')
# (7, 7, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12338274.pdf')
# (8, 8, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12442909.pdf')
# (9, 9, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12780508.pdf')
# (10, 10, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12802330.pdf')
# (11, 11, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13072019.pdf')
# (12, 12, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13130984.pdf')
# (13, 13, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13294301.pdf')
# (14, 14, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13491889.pdf')
# (15, 15, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13701259.pdf')
# (16, 16, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14055988.pdf')
# (17, 3, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14126433.pdf')
# (18, 17, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14224370.pdf')
# (19, 2, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14449423.pdf')
# (20, 18, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14470533.pdf')
# (21, 19, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10186968.pdf')
# (22, 20, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10344379.pdf')
# (23, 21, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10659182.pdf')
# (24, 22, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10818478.pdf')
# (25, 23, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11174187.pdf')
# (26, 18, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11188218.pdf')
# (27, 24, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11773767.pdf')
# (28, 25, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11963737.pdf')
# (29, 26, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\12171093.pdf')
# (30, 27, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\12544735.pdf')
# (31, 28, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13072354.pdf')
# (32, 29, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13115648.pdf')
# (33, 30, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13342150.pdf')
# (34, 31, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13593241.pdf')
# (35, 32, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13809698.pdf')
# (36, 33, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13909762.pdf')
# (37, 34, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13967854.pdf')
# (38, 35, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\14064815.pdf')
# (39, 36, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\14146106.pdf')
# (40, 37, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\14176254.pdf')
# (41, 38, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\10953078.pdf')
# (42, 39, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\11197262.pdf')
# (43, 40, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\11676151.pdf')
# (44, 12, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\11813872.pdf')
# (45, 41, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\12341902.pdf')
# (46, 42, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\12674256.pdf')
# (47, 43, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\14140903.pdf')
# (48, 44, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\15053703.pdf')
# (49, 45, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\15546686.pdf')
# (50, 46, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\15603319.pdf')
# (51, 34, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16172429.pdf')
# (52, 47, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16507693.pdf')
# (53, 8, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16653657.pdf')
# (54, 48, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16661264.pdf')
# (55, 49, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16849128.pdf')
# (56, 50, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\17312146.pdf')
# (57, 51, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\17499196.pdf')
# (58, 52, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\17640785.pdf')
# (59, 53, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\18242317.pdf')
# (60, 54, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\18264694.pdf')
# (61, 55, 'APPAREL', 'archive\\data\\data\\APPAREL\\10182582.pdf')
# (62, 2, 'APPAREL', 'archive\\data\\data\\APPAREL\\10562768.pdf')
# (63, 56, 'APPAREL', 'archive\\data\\data\\APPAREL\\10738095.pdf')
# (64, 57, 'APPAREL', 'archive\\data\\data\\APPAREL\\10876132.pdf')
# (65, 58, 'APPAREL', 'archive\\data\\data\\APPAREL\\11232471.pdf')
# (66, 59, 'APPAREL', 'archive\\data\\data\\APPAREL\\11409460.pdf')
# (67, 60, 'APPAREL', 'archive\\data\\data\\APPAREL\\11677077.pdf')
# (68, 61, 'APPAREL', 'archive\\data\\data\\APPAREL\\12059610.pdf')
# (69, 62, 'APPAREL', 'archive\\data\\data\\APPAREL\\12122372.pdf')
# (70, 63, 'APPAREL', 'archive\\data\\data\\APPAREL\\12668625.pdf')
# (71, 64, 'APPAREL', 'archive\\data\\data\\APPAREL\\12669075.pdf')
# (72, 65, 'APPAREL', 'archive\\data\\data\\APPAREL\\12860543.pdf')
# (73, 66, 'APPAREL', 'archive\\data\\data\\APPAREL\\13386301.pdf')
# (74, 67, 'APPAREL', 'archive\\data\\data\\APPAREL\\13418452.pdf')
# (75, 68, 'APPAREL', 'archive\\data\\data\\APPAREL\\13764840.pdf')
# (76, 48, 'APPAREL', 'archive\\data\\data\\APPAREL\\13807808.pdf')
# (77, 69, 'APPAREL', 'archive\\data\\data\\APPAREL\\13858219.pdf')
# (78, 36, 'APPAREL', 'archive\\data\\data\\APPAREL\\14304010.pdf')
# (79, 70, 'APPAREL', 'archive\\data\\data\\APPAREL\\14413257.pdf')
# (80, 71, 'APPAREL', 'archive\\data\\data\\APPAREL\\14698557.pdf')
# (81, 72, 'ARTS', 'archive\\data\\data\\ARTS\\10830646.pdf')
# (82, 73, 'ARTS', 'archive\\data\\data\\ARTS\\11187796.pdf')
# (83, 74, 'ARTS', 'archive\\data\\data\\ARTS\\11360471.pdf')
# (84, 24, 'ARTS', 'archive\\data\\data\\ARTS\\11555549.pdf')
# (85, 52, 'ARTS', 'archive\\data\\data\\ARTS\\11995013.pdf')
# (86, 75, 'ARTS', 'archive\\data\\data\\ARTS\\12334650.pdf')
# (87, 76, 'ARTS', 'archive\\data\\data\\ARTS\\12386670.pdf')
# (88, 73, 'ARTS', 'archive\\data\\data\\ARTS\\12413512.pdf')
# (89, 77, 'ARTS', 'archive\\data\\data\\ARTS\\12777487.pdf')
# (90, 78, 'ARTS', 'archive\\data\\data\\ARTS\\13272204.pdf')
# (91, 36, 'ARTS', 'archive\\data\\data\\ARTS\\14150896.pdf')
# (92, 68, 'ARTS', 'archive\\data\\data\\ARTS\\14248724.pdf')
# (93, 37, 'ARTS', 'archive\\data\\data\\ARTS\\14879257.pdf')
# (94, 79, 'ARTS', 'archive\\data\\data\\ARTS\\15265464.pdf')
# (95, 80, 'ARTS', 'archive\\data\\data\\ARTS\\15306049.pdf')
# (96, 77, 'ARTS', 'archive\\data\\data\\ARTS\\16244633.pdf')
# (97, 81, 'ARTS', 'archive\\data\\data\\ARTS\\16887936.pdf')
# (98, 82, 'ARTS', 'archive\\data\\data\\ARTS\\16962067.pdf')
# (99, 83, 'ARTS', 'archive\\data\\data\\ARTS\\17033567.pdf')
# (100, 84, 'ARTS', 'archive\\data\\data\\ARTS\\17325147.pdf')
# (101, 24, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11152490.pdf')
# (102, 85, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11257723.pdf')
# (103, 86, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11797122.pdf')
# (104, 84, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11887930.pdf')
# (105, 20, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\14455622.pdf')
# (106, 10, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\14508237.pdf')
# (107, 87, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15100547.pdf')
# (108, 88, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15210069.pdf')
# (109, 73, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15484011.pdf')
# (110, 68, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15790602.pdf')
# (111, 86, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\16332293.pdf')
# (112, 89, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\17510973.pdf')
# (113, 90, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\17571262.pdf')
# (114, 58, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\18448085.pdf')
# (115, 91, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\18932512.pdf')
# (116, 92, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\22452756.pdf')
# (117, 93, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\22732234.pdf')
# (118, 72, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\22946204.pdf')
# (119, 94, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\23009962.pdf')
# (120, 95, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\23522150.pdf')
# (121, 96, 'AVIATION', 'archive\\data\\data\\AVIATION\\10176815.pdf')
# (122, 97, 'AVIATION', 'archive\\data\\data\\AVIATION\\10189110.pdf')
# (123, 30, 'AVIATION', 'archive\\data\\data\\AVIATION\\10395944.pdf')
# (124, 59, 'AVIATION', 'archive\\data\\data\\AVIATION\\10567764.pdf')
# (125, 98, 'AVIATION', 'archive\\data\\data\\AVIATION\\10945968.pdf')
# (126, 99, 'AVIATION', 'archive\\data\\data\\AVIATION\\11137306.pdf')
# (127, 100, 'AVIATION', 'archive\\data\\data\\AVIATION\\11169163.pdf')
# (128, 101, 'AVIATION', 'archive\\data\\data\\AVIATION\\11333001.pdf')
# (129, 102, 'AVIATION', 'archive\\data\\data\\AVIATION\\11614114.pdf')
# (130, 33, 'AVIATION', 'archive\\data\\data\\AVIATION\\11752500.pdf')
# (131, 44, 'AVIATION', 'archive\\data\\data\\AVIATION\\11804712.pdf')
# (132, 38, 'AVIATION', 'archive\\data\\data\\AVIATION\\11959428.pdf')
# (133, 80, 'AVIATION', 'archive\\data\\data\\AVIATION\\12043694.pdf')
# (134, 103, 'AVIATION', 'archive\\data\\data\\AVIATION\\12144825.pdf')
# (135, 75, 'AVIATION', 'archive\\data\\data\\AVIATION\\12192507.pdf')
# (136, 104, 'AVIATION', 'archive\\data\\data\\AVIATION\\12239749.pdf')
# (137, 105, 'AVIATION', 'archive\\data\\data\\AVIATION\\12504278.pdf')
# (138, 106, 'AVIATION', 'archive\\data\\data\\AVIATION\\12904972.pdf')
# (139, 107, 'AVIATION', 'archive\\data\\data\\AVIATION\\13195436.pdf')
# (140, 108, 'AVIATION', 'archive\\data\\data\\AVIATION\\13234267.pdf')
# (141, 104, 'BANKING', 'archive\\data\\data\\BANKING\\10329506.pdf')
# (142, 109, 'BANKING', 'archive\\data\\data\\BANKING\\10909673.pdf')
# (143, 110, 'BANKING', 'archive\\data\\data\\BANKING\\11065180.pdf')
# (144, 111, 'BANKING', 'archive\\data\\data\\BANKING\\11262933.pdf')
# (145, 112, 'BANKING', 'archive\\data\\data\\BANKING\\11266906.pdf')
# (146, 113, 'BANKING', 'archive\\data\\data\\BANKING\\11637468.pdf')
# (147, 114, 'BANKING', 'archive\\data\\data\\BANKING\\11672279.pdf')
# (148, 115, 'BANKING', 'archive\\data\\data\\BANKING\\11773925.pdf')
# (149, 116, 'BANKING', 'archive\\data\\data\\BANKING\\11842348.pdf')
# (150, 117, 'BANKING', 'archive\\data\\data\\BANKING\\12021752.pdf')
# (151, 118, 'BANKING', 'archive\\data\\data\\BANKING\\13173522.pdf')
# (152, 119, 'BANKING', 'archive\\data\\data\\BANKING\\13393401.pdf')
# (153, 120, 'BANKING', 'archive\\data\\data\\BANKING\\13982572.pdf')
# (154, 50, 'BANKING', 'archive\\data\\data\\BANKING\\14391434.pdf')
# (155, 102, 'BANKING', 'archive\\data\\data\\BANKING\\14626780.pdf')
# (156, 121, 'BANKING', 'archive\\data\\data\\BANKING\\15553584.pdf')
# (157, 52, 'BANKING', 'archive\\data\\data\\BANKING\\15856762.pdf')
# (158, 33, 'BANKING', 'archive\\data\\data\\BANKING\\16300459.pdf')
# (159, 114, 'BANKING', 'archive\\data\\data\\BANKING\\16407619.pdf')
# (160, 122, 'BANKING', 'archive\\data\\data\\BANKING\\17131084.pdf')
# (161, 90, 'BPO', 'archive\\data\\data\\BPO\\11183737.pdf')
# (162, 123, 'BPO', 'archive\\data\\data\\BPO\\13964744.pdf')
# (163, 11, 'BPO', 'archive\\data\\data\\BPO\\15145575.pdf')
# (164, 69, 'BPO', 'archive\\data\\data\\BPO\\15573418.pdf')
# (165, 16, 'BPO', 'archive\\data\\data\\BPO\\16492045.pdf')
# (166, 124, 'BPO', 'archive\\data\\data\\BPO\\18589927.pdf')
# (167, 11, 'BPO', 'archive\\data\\data\\BPO\\19362586.pdf')
# (168, 123, 'BPO', 'archive\\data\\data\\BPO\\23933031.pdf')
# (169, 80, 'BPO', 'archive\\data\\data\\BPO\\24727739.pdf')
# (170, 125, 'BPO', 'archive\\data\\data\\BPO\\26829350.pdf')
# (171, 126, 'BPO', 'archive\\data\\data\\BPO\\27710853.pdf')
# (172, 42, 'BPO', 'archive\\data\\data\\BPO\\30709029.pdf')
# (173, 127, 'BPO', 'archive\\data\\data\\BPO\\31064969.pdf')
# (174, 60, 'BPO', 'archive\\data\\data\\BPO\\38707449.pdf')
# (175, 118, 'BPO', 'archive\\data\\data\\BPO\\41152404.pdf')
# (176, 128, 'BPO', 'archive\\data\\data\\BPO\\45077654.pdf')
# (177, 96, 'BPO', 'archive\\data\\data\\BPO\\57706851.pdf')
# (178, 129, 'BPO', 'archive\\data\\data\\BPO\\63158213.pdf')
# (179, 66, 'BPO', 'archive\\data\\data\\BPO\\69097572.pdf')
# (180, 130, 'BPO', 'archive\\data\\data\\BPO\\79261033.pdf')
# (181, 97, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10228751.pdf')
# (182, 5, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10235211.pdf')
# (183, 110, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10289113.pdf')
# (184, 131, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10501991.pdf')
# (185, 132, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10541358.pdf')
# (186, 75, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10704573.pdf')
# (187, 133, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\11088337.pdf')
# (188, 134, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\11289482.pdf')
# (189, 112, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\11551946.pdf')
# (190, 16, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12059198.pdf')
# (191, 36, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12230301.pdf')
# (192, 135, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12377803.pdf')
# (193, 50, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12546838.pdf')
# (194, 136, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12632728.pdf')
# (195, 137, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12814706.pdf')
# (196, 62, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13080868.pdf')
# (197, 27, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13199813.pdf')
# (198, 138, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13574264.pdf')
# (199, 83, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13888506.pdf')
# (200, 95, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\14055971.pdf')
# (201, 139, 'CHEF', 'archive\\data\\data\\CHEF\\10001727.pdf')
# (202, 54, 'CHEF', 'archive\\data\\data\\CHEF\\10276858.pdf')
# (203, 100, 'CHEF', 'archive\\data\\data\\CHEF\\10333299.pdf')
# (204, 29, 'CHEF', 'archive\\data\\data\\CHEF\\10588874.pdf')
# (205, 140, 'CHEF', 'archive\\data\\data\\CHEF\\10653119.pdf')
# (206, 75, 'CHEF', 'archive\\data\\data\\CHEF\\10889157.pdf')
# (207, 81, 'CHEF', 'archive\\data\\data\\CHEF\\11121498.pdf')
# (208, 101, 'CHEF', 'archive\\data\\data\\CHEF\\11209758.pdf')
# (209, 141, 'CHEF', 'archive\\data\\data\\CHEF\\11432686.pdf')
# (210, 1, 'CHEF', 'archive\\data\\data\\CHEF\\11444536.pdf')
# (211, 9, 'CHEF', 'archive\\data\\data\\CHEF\\12155206.pdf')
# (212, 132, 'CHEF', 'archive\\data\\data\\CHEF\\12254068.pdf')
# (213, 130, 'CHEF', 'archive\\data\\data\\CHEF\\12420359.pdf')
# (214, 23, 'CHEF', 'archive\\data\\data\\CHEF\\12717345.pdf')
# (215, 66, 'CHEF', 'archive\\data\\data\\CHEF\\13095891.pdf')
# (216, 103, 'CHEF', 'archive\\data\\data\\CHEF\\13212436.pdf')
# (217, 142, 'CHEF', 'archive\\data\\data\\CHEF\\13264154.pdf')
# (218, 143, 'CHEF', 'archive\\data\\data\\CHEF\\13411858.pdf')
# (219, 9, 'CHEF', 'archive\\data\\data\\CHEF\\14569498.pdf')
# (220, 27, 'CHEF', 'archive\\data\\data\\CHEF\\14663897.pdf')
# (221, 69, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10041713.pdf')
# (222, 86, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10100240.pdf')
# (223, 91, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10149490.pdf')
# (224, 4, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10176013.pdf')
# (225, 144, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10281555.pdf')
# (226, 93, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10734870.pdf')
# (227, 145, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10820510.pdf')
# (228, 133, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\11393213.pdf')
# (229, 62, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\11650031.pdf')
# (230, 68, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12212468.pdf')
# (231, 146, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12491898.pdf')
# (232, 147, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12654876.pdf')
# (233, 57, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12666174.pdf')
# (234, 148, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12693146.pdf')
# (235, 13, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12695537.pdf')
# (236, 91, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12826414.pdf')
# (237, 149, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12839152.pdf')
# (238, 83, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12890045.pdf')
# (239, 52, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\13907230.pdf')
# (240, 129, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\14585273.pdf')
# (241, 143, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\10332998.pdf')
# (242, 17, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\10984392.pdf')
# (243, 148, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11020140.pdf')
# (244, 75, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11333660.pdf')
# (245, 71, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11415967.pdf')
# (246, 150, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11835339.pdf')
# (247, 131, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12251115.pdf')
# (248, 54, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12374933.pdf')
# (249, 73, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12526702.pdf')
# (250, 151, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12897903.pdf')
# (251, 62, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12955994.pdf')
# (252, 152, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13215696.pdf')
# (253, 117, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13313917.pdf')
# (254, 42, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13454871.pdf')
# (255, 18, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13569152.pdf')
# (256, 77, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13586069.pdf')
# (257, 76, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\14346702.pdf')
# (258, 153, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\14517953.pdf')
# (259, 142, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\14593060.pdf')
# (260, 21, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\15083600.pdf')
# (261, 41, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\10466583.pdf')
# (262, 154, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\10748989.pdf')
# (263, 82, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\10751444.pdf')
# (264, 82, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11155153.pdf')
# (265, 15, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11722421.pdf')
# (266, 88, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11807040.pdf')
# (267, 58, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11919526.pdf')
# (268, 63, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11958994.pdf')
# (269, 155, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\12415691.pdf')
# (270, 153, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\12547982.pdf')
# (271, 156, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\12674307.pdf')
# (272, 20, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13014900.pdf')
# (273, 25, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13518263.pdf')
# (274, 67, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13557622.pdf')
# (275, 26, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13774329.pdf')
# (276, 77, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13998435.pdf')
# (277, 41, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14014749.pdf')
# (278, 140, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14528265.pdf')
# (279, 125, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14724186.pdf')
# (280, 110, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14743911.pdf')
# (281, 54, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\10005171.pdf')
# (282, 125, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\10515955.pdf')
# (283, 157, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\11005406.pdf')
# (284, 158, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\11270462.pdf')
# (285, 159, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\11677012.pdf')
# (286, 107, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\12085736.pdf')
# (287, 119, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13328680.pdf')
# (288, 31, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13343786.pdf')
# (289, 144, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13503650.pdf')
# (290, 157, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13837784.pdf')
# (291, 66, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14036515.pdf')
# (292, 138, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14209965.pdf')
# (293, 160, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14556869.pdf')
# (294, 61, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14761906.pdf')
# (295, 161, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14771530.pdf')
# (296, 63, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14945250.pdf')
# (297, 152, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\15226699.pdf')
# (298, 116, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\15353911.pdf')
# (299, 53, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\15484097.pdf')
# (300, 78, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\16276121.pdf')
# (301, 162, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10030015.pdf')
# (302, 38, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10219099.pdf')
# (303, 163, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10624813.pdf')
# (304, 13, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10712803.pdf')
# (305, 56, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10985403.pdf')
# (306, 125, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\11890896.pdf')
# (307, 20, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\11981094.pdf')
# (308, 73, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12011623.pdf')
# (309, 113, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12022566.pdf')
# (310, 91, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12472574.pdf')
# (311, 24, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12488356.pdf')
# (312, 151, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12518008.pdf')
# (313, 123, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12748557.pdf')
# (314, 143, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\13149176.pdf')
# (315, 96, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\13264796.pdf')
# (316, 164, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\14049846.pdf')
# (317, 125, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\14206561.pdf')
# (318, 82, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\14554542.pdf')
# (319, 43, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\15139979.pdf')
# (320, 73, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\15601399.pdf')
# (321, 70, 'FINANCE', 'archive\\data\\data\\FINANCE\\10549585.pdf')
# (322, 107, 'FINANCE', 'archive\\data\\data\\FINANCE\\11441764.pdf')
# (323, 37, 'FINANCE', 'archive\\data\\data\\FINANCE\\11490673.pdf')
# (324, 62, 'FINANCE', 'archive\\data\\data\\FINANCE\\11877150.pdf')
# (325, 20, 'FINANCE', 'archive\\data\\data\\FINANCE\\12071138.pdf')
# (326, 91, 'FINANCE', 'archive\\data\\data\\FINANCE\\12858898.pdf')
# (327, 108, 'FINANCE', 'archive\\data\\data\\FINANCE\\14106638.pdf')
# (328, 146, 'FINANCE', 'archive\\data\\data\\FINANCE\\14181049.pdf')
# (329, 124, 'FINANCE', 'archive\\data\\data\\FINANCE\\14408510.pdf')
# (330, 73, 'FINANCE', 'archive\\data\\data\\FINANCE\\14413148.pdf')
# (331, 14, 'FINANCE', 'archive\\data\\data\\FINANCE\\14722634.pdf')
# (332, 28, 'FINANCE', 'archive\\data\\data\\FINANCE\\15011085.pdf')
# (333, 66, 'FINANCE', 'archive\\data\\data\\FINANCE\\15224503.pdf')
# (334, 92, 'FINANCE', 'archive\\data\\data\\FINANCE\\15717923.pdf')
# (335, 55, 'FINANCE', 'archive\\data\\data\\FINANCE\\15792052.pdf')
# (336, 165, 'FINANCE', 'archive\\data\\data\\FINANCE\\15891494.pdf')
# (337, 156, 'FINANCE', 'archive\\data\\data\\FINANCE\\16426777.pdf')
# (338, 139, 'FINANCE', 'archive\\data\\data\\FINANCE\\16449850.pdf')
# (339, 46, 'FINANCE', 'archive\\data\\data\\FINANCE\\17392859.pdf')
# (340, 110, 'FINANCE', 'archive\\data\\data\\FINANCE\\17775916.pdf')
# (341, 79, 'FITNESS', 'archive\\data\\data\\FITNESS\\10235429.pdf')
# (342, 139, 'FITNESS', 'archive\\data\\data\\FITNESS\\10268614.pdf')
# (343, 100, 'FITNESS', 'archive\\data\\data\\FITNESS\\10333051.pdf')
# (344, 166, 'FITNESS', 'archive\\data\\data\\FITNESS\\10428916.pdf')
# (345, 82, 'FITNESS', 'archive\\data\\data\\FITNESS\\10568350.pdf')
# (346, 7, 'FITNESS', 'archive\\data\\data\\FITNESS\\10816645.pdf')
# (347, 142, 'FITNESS', 'archive\\data\\data\\FITNESS\\10969918.pdf')
# (348, 167, 'FITNESS', 'archive\\data\\data\\FITNESS\\11130200.pdf')
# (349, 168, 'FITNESS', 'archive\\data\\data\\FITNESS\\11332602.pdf')
# (350, 82, 'FITNESS', 'archive\\data\\data\\FITNESS\\11522068.pdf')
# (351, 169, 'FITNESS', 'archive\\data\\data\\FITNESS\\12019284.pdf')
# (352, 146, 'FITNESS', 'archive\\data\\data\\FITNESS\\12092347.pdf')
# (353, 170, 'FITNESS', 'archive\\data\\data\\FITNESS\\12695799.pdf')
# (354, 46, 'FITNESS', 'archive\\data\\data\\FITNESS\\12791244.pdf')
# (355, 37, 'FITNESS', 'archive\\data\\data\\FITNESS\\12923795.pdf')
# (356, 97, 'FITNESS', 'archive\\data\\data\\FITNESS\\12938389.pdf')
# (357, 4, 'FITNESS', 'archive\\data\\data\\FITNESS\\13037145.pdf')
# (358, 63, 'FITNESS', 'archive\\data\\data\\FITNESS\\13367322.pdf')
# (359, 171, 'FITNESS', 'archive\\data\\data\\FITNESS\\13675377.pdf')
# (360, 52, 'FITNESS', 'archive\\data\\data\\FITNESS\\14107571.pdf')
# (361, 156, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10062724.pdf')
# (362, 30, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10076271.pdf')
# (363, 75, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10251432.pdf')
# (364, 43, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10466208.pdf')
# (365, 164, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10480456.pdf')
# (366, 89, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10568183.pdf')
# (367, 129, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11378657.pdf')
# (368, 16, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11605833.pdf')
# (369, 72, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11653906.pdf')
# (370, 172, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11704150.pdf')
# (371, 173, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12315079.pdf')
# (372, 11, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12333703.pdf')
# (373, 81, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12613221.pdf')
# (374, 36, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12938200.pdf')
# (375, 174, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\13352113.pdf')
# (376, 100, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\13565152.pdf')
# (377, 26, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\13575312.pdf')
# (378, 75, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\14062078.pdf')
# (379, 33, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\14667957.pdf')
# (380, 159, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\15499825.pdf')
# (381, 175, 'HR', 'archive\\data\\data\\HR\\10399912.pdf')
# (382, 16, 'HR', 'archive\\data\\data\\HR\\10694288.pdf')
# (383, 96, 'HR', 'archive\\data\\data\\HR\\11480899.pdf')
# (384, 13, 'HR', 'archive\\data\\data\\HR\\11592605.pdf')
# (385, 68, 'HR', 'archive\\data\\data\\HR\\11698189.pdf')
# (386, 82, 'HR', 'archive\\data\\data\\HR\\11763983.pdf')
# (387, 97, 'HR', 'archive\\data\\data\\HR\\11847784.pdf')
# (388, 135, 'HR', 'archive\\data\\data\\HR\\12786012.pdf')
# (389, 79, 'HR', 'archive\\data\\data\\HR\\13376919.pdf')
# (390, 176, 'HR', 'archive\\data\\data\\HR\\13520837.pdf')
# (391, 43, 'HR', 'archive\\data\\data\\HR\\13879043.pdf')
# (392, 123, 'HR', 'archive\\data\\data\\HR\\14225422.pdf')
# (393, 13, 'HR', 'archive\\data\\data\\HR\\14256329.pdf')
# (394, 118, 'HR', 'archive\\data\\data\\HR\\14640322.pdf')
# (395, 105, 'HR', 'archive\\data\\data\\HR\\14886205.pdf')
# (396, 62, 'HR', 'archive\\data\\data\\HR\\15041689.pdf')
# (397, 67, 'HR', 'archive\\data\\data\\HR\\15375009.pdf')
# (398, 156, 'HR', 'archive\\data\\data\\HR\\15575117.pdf')
# (399, 58, 'HR', 'archive\\data\\data\\HR\\15576950.pdf')
# (400, 177, 'HR', 'archive\\data\\data\\HR\\16852973.pdf')
# (401, 22, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10089434.pdf')
# (402, 97, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10247517.pdf')
# (403, 94, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10265057.pdf')
# (404, 100, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10553553.pdf')
# (405, 124, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10641230.pdf')
# (406, 22, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10839851.pdf')
# (407, 112, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10840430.pdf')
# (408, 134, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\11580408.pdf')
# (409, 119, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\11584809.pdf')
# (410, 45, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\11957080.pdf')
# (411, 5, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12045067.pdf')
# (412, 18, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12334140.pdf')
# (413, 63, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12635195.pdf')
# (414, 114, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12763627.pdf')
# (415, 14, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13385306.pdf')
# (416, 167, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13405733.pdf')
# (417, 49, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13477922.pdf')
# (418, 92, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13836471.pdf')
# (419, 153, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\14789139.pdf')
# (420, 139, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\15118506.pdf')
# (421, 23, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10070224.pdf')
# (422, 115, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10554045.pdf')
# (423, 178, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10873344.pdf')
# (424, 161, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10926726.pdf')
# (425, 101, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11160414.pdf')
# (426, 54, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11624880.pdf')
# (427, 152, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11635137.pdf')
# (428, 12, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11842274.pdf')
# (429, 6, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11850315.pdf')
# (430, 105, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11902276.pdf')
# (431, 142, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12191094.pdf')
# (432, 147, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12237267.pdf')
# (433, 119, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12545844.pdf')
# (434, 179, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12567516.pdf')
# (435, 145, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12920612.pdf')
# (436, 6, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\13129275.pdf')
# (437, 180, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\13727873.pdf')
# (438, 181, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\13915715.pdf')
# (439, 117, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\14009087.pdf')
# (440, 92, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\14128006.pdf')
# (441, 121, 'SALES', 'archive\\data\\data\\SALES\\10138632.pdf')
# (442, 59, 'SALES', 'archive\\data\\data\\SALES\\10464113.pdf')
# (443, 138, 'SALES', 'archive\\data\\data\\SALES\\10603337.pdf')
# (444, 101, 'SALES', 'archive\\data\\data\\SALES\\10724818.pdf')
# (445, 74, 'SALES', 'archive\\data\\data\\SALES\\10898339.pdf')
# (446, 50, 'SALES', 'archive\\data\\data\\SALES\\12082377.pdf')
# (447, 151, 'SALES', 'archive\\data\\data\\SALES\\12351749.pdf')
# (448, 105, 'SALES', 'archive\\data\\data\\SALES\\12696104.pdf')
# (449, 90, 'SALES', 'archive\\data\\data\\SALES\\12820557.pdf')
# (450, 171, 'SALES', 'archive\\data\\data\\SALES\\13178604.pdf')
# (451, 79, 'SALES', 'archive\\data\\data\\SALES\\13348915.pdf')
# (452, 182, 'SALES', 'archive\\data\\data\\SALES\\13637605.pdf')
# (453, 116, 'SALES', 'archive\\data\\data\\SALES\\13812481.pdf')
# (454, 78, 'SALES', 'archive\\data\\data\\SALES\\14267489.pdf')
# (455, 65, 'SALES', 'archive\\data\\data\\SALES\\14358578.pdf')
# (456, 81, 'SALES', 'archive\\data\\data\\SALES\\14381464.pdf')
# (457, 183, 'SALES', 'archive\\data\\data\\SALES\\15273850.pdf')
# (458, 184, 'SALES', 'archive\\data\\data\\SALES\\15581242.pdf')
# (459, 149, 'SALES', 'archive\\data\\data\\SALES\\15620421.pdf')
# (460, 69, 'SALES', 'archive\\data\\data\\SALES\\15765660.pdf')
# (461, 152, 'TEACHER', 'archive\\data\\data\\TEACHER\\10504237.pdf')
# (462, 137, 'TEACHER', 'archive\\data\\data\\TEACHER\\10527994.pdf')
# (463, 64, 'TEACHER', 'archive\\data\\data\\TEACHER\\10909720.pdf')
# (464, 185, 'TEACHER', 'archive\\data\\data\\TEACHER\\11336022.pdf')
# (465, 2, 'TEACHER', 'archive\\data\\data\\TEACHER\\11616482.pdf')
# (466, 109, 'TEACHER', 'archive\\data\\data\\TEACHER\\11943065.pdf')
# (467, 182, 'TEACHER', 'archive\\data\\data\\TEACHER\\12467531.pdf')
# (468, 139, 'TEACHER', 'archive\\data\\data\\TEACHER\\12587973.pdf')
# (469, 10, 'TEACHER', 'archive\\data\\data\\TEACHER\\13087952.pdf')
# (470, 186, 'TEACHER', 'archive\\data\\data\\TEACHER\\13296856.pdf')
# (471, 26, 'TEACHER', 'archive\\data\\data\\TEACHER\\13330982.pdf')
# (472, 187, 'TEACHER', 'archive\\data\\data\\TEACHER\\13583538.pdf')
# (473, 92, 'TEACHER', 'archive\\data\\data\\TEACHER\\13855004.pdf')
# (474, 68, 'TEACHER', 'archive\\data\\data\\TEACHER\\14958913.pdf')
# (475, 119, 'TEACHER', 'archive\\data\\data\\TEACHER\\15850434.pdf')
# (476, 86, 'TEACHER', 'archive\\data\\data\\TEACHER\\15899269.pdf')
# (477, 23, 'TEACHER', 'archive\\data\\data\\TEACHER\\16210888.pdf')
# (478, 124, 'TEACHER', 'archive\\data\\data\\TEACHER\\16270906.pdf')
# (479, 188, 'TEACHER', 'archive\\data\\data\\TEACHER\\16820422.pdf')
# (480, 98, 'TEACHER', 'archive\\data\\data\\TEACHER\\17311685.pdf')
