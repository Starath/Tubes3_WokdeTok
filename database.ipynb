# %%
import mysql.connector
import os
import random
from faker import Faker
import re

# %%
fake = Faker()

class ATSDatabase:
    def __init__(self):
        self.conn = mysql.connector.connect(
            host='ats-database-fareltaza35-4318.b.aivencloud.com',
            user='avnadmin',
            password='AVNS_wk8smk5E9W1DPhrWb3D',
            database='defaultdb',
            port=24585,
        )
        self.cursor = self.conn.cursor()
        self.create_tables()
    
    def create_tables(self):
        self.cursor.execute('''
            CREATE TABLE IF NOT EXISTS applicantprofile (
                applicant_id INT AUTO_INCREMENT PRIMARY KEY,
                first_name VARCHAR(50),
                last_name VARCHAR(50),
                date_of_birth DATE,
                address VARCHAR(255),
                phone_number VARCHAR(20)
            )
        ''')

        self.cursor.execute('''
            CREATE TABLE IF NOT EXISTS applicationdetail (
                detail_id INT AUTO_INCREMENT PRIMARY KEY,
                applicant_id INT NOT NULL,
                applicant_role VARCHAR(100),
                cv_path TEXT,
                FOREIGN KEY (applicant_id) REFERENCES applicantprofile(applicant_id)
            )
        ''')
        self.conn.commit()

    def add_applicant(self, first_name, last_name, date_of_birth, address, phone_number):
        self.cursor.execute('''
            INSERT INTO applicantprofile (first_name, last_name, date_of_birth, address, phone_number)
            VALUES (%s, %s, %s, %s, %s)
        ''', (first_name, last_name, date_of_birth, address, phone_number))
        self.conn.commit()

    def get_applicant_id(self, first_name, last_name):
        self.cursor.execute('''
            SELECT applicant_id FROM applicantprofile
            WHERE first_name=%s AND last_name=%s
        ''', (first_name, last_name))
        result = self.cursor.fetchone()
        return result[0] if result else None

    def get_or_create_applicant(self, first_name, last_name, date_of_birth="", address="", phone_number=""):
        applicant_id = self.get_applicant_id(first_name, last_name)
        if not applicant_id:
            self.add_applicant(first_name, last_name, date_of_birth, address, phone_number)
            applicant_id = self.cursor.lastrowid
        return applicant_id

    def add_application(self, applicant_id, applicant_role, cv_path):
        self.cursor.execute('''
            INSERT INTO applicationdetail (applicant_id, applicant_role, cv_path)
            VALUES (%s, %s, %s)
        ''', (applicant_id, applicant_role, cv_path))
        self.conn.commit()

    def save_cv_to_database(self, first_name, last_name, applicant_role, cv_path):
        date_of_birth = fake.date_of_birth(minimum_age=18, maximum_age=60).strftime("%Y-%m-%d")
        address = fake.address().replace('\n', ', ')
        phone_number = re.sub(r'[^\d+]', '', fake.phone_number())[:20]
        applicant_id = self.get_or_create_applicant(first_name, last_name, date_of_birth, address, phone_number)
        self.add_application(applicant_id, applicant_role, cv_path)

    def get_all_applicants(self):
        self.cursor.execute('SELECT * FROM applicantprofile')
        return self.cursor.fetchall()

    def get_all_applications(self):
        self.cursor.execute('SELECT * FROM applicationdetail')
        return self.cursor.fetchall()

    def update_applicant(self, applicant_id, first_name, last_name, date_of_birth, address, phone_number):
        self.cursor.execute('''
            UPDATE applicantprofile
            SET first_name=%s, last_name=%s, date_of_birth=%s, address=%s, phone_number=%s
            WHERE applicant_id=%s
        ''', (first_name, last_name, date_of_birth, address, phone_number, applicant_id))
        self.conn.commit()

    def delete_applicant(self, applicant_id):
        self.cursor.execute('DELETE FROM applicantprofile WHERE applicant_id=%s', (applicant_id,))
        self.conn.commit()

    def update_application(self, detail_id, applicant_id, applicant_role, cv_path):
        self.cursor.execute('''
            UPDATE applicationdetail
            SET applicant_id=%s, applicant_role=%s, cv_path=%s
            WHERE detail_id=%s
        ''', (applicant_id, applicant_role, cv_path, detail_id))
        self.conn.commit()

    def delete_application(self, detail_id):
        self.cursor.execute('DELETE FROM applicationdetail WHERE detail_id=%s', (detail_id,))
        self.conn.commit()

    def close(self):
        self.conn.close()

# %%
def read_file(root_dir):
    ats_db = ATSDatabase()  

    first_names = ['John', 'Supri', 'Jane', 'Alex', 'Emily', 'Asep', 'Jajang', 'Chris', 'Katie', 'Dadang', 'Michael', 'Sara', 'Cecep', 'David', 'Laura']
    last_names = ['Smith', 'Saepuloh', 'Johnson', 'Williams', 'Suherman', 'Brown', 'Jones', 'Garcia', 'Sumarna', 'Miller', 'Davis', 'Santosa', 'Martinez', 'Hernandez']
    
    for category in os.listdir(root_dir):
        category_path = os.path.join(root_dir, category)

        if os.path.isdir(category_path): 
            print(f"Processing category: {category}")

            pdf_files = [f for f in os.listdir(category_path) if f.endswith('.pdf')][:20]

            for pdf_file in pdf_files:
                pdf_path = os.path.join(category_path, pdf_file)
                print(f"Processing CV: {pdf_file}")

                ats_db.save_cv_to_database(first_name=random.choice(first_names), 
                                            last_name=random.choice(last_names), 
                                            applicant_role=category, 
                                            cv_path=pdf_path)

    ats_db.close()

# %%
read_file('archive\data\data')
# Out:
# Processing category: ACCOUNTANT
# Processing CV: 10554236.pdf
# Processing CV: 10674770.pdf
# Processing CV: 11163645.pdf
# Processing CV: 11759079.pdf
# Processing CV: 12065211.pdf
# Processing CV: 12202337.pdf
# Processing CV: 12338274.pdf
# Processing CV: 12442909.pdf
# Processing CV: 12780508.pdf
# Processing CV: 12802330.pdf
# Processing CV: 13072019.pdf
# Processing CV: 13130984.pdf
# Processing CV: 13294301.pdf
# Processing CV: 13491889.pdf
# Processing CV: 13701259.pdf
# Processing CV: 14055988.pdf
# Processing CV: 14126433.pdf
# Processing CV: 14224370.pdf
# Processing CV: 14449423.pdf
# Processing CV: 14470533.pdf
# Processing category: ADVOCATE
# Processing CV: 10186968.pdf
# Processing CV: 10344379.pdf
# Processing CV: 10659182.pdf
# Processing CV: 10818478.pdf
# Processing CV: 11174187.pdf
# Processing CV: 11188218.pdf
# Processing CV: 11773767.pdf
# Processing CV: 11963737.pdf
# Processing CV: 12171093.pdf
# Processing CV: 12544735.pdf
# Processing CV: 13072354.pdf
# Processing CV: 13115648.pdf
# Processing CV: 13342150.pdf
# Processing CV: 13593241.pdf
# Processing CV: 13809698.pdf
# Processing CV: 13909762.pdf
# Processing CV: 13967854.pdf
# Processing CV: 14064815.pdf
# Processing CV: 14146106.pdf
# Processing CV: 14176254.pdf
# Processing category: AGRICULTURE
# Processing CV: 10953078.pdf
# Processing CV: 11197262.pdf
# Processing CV: 11676151.pdf
# Processing CV: 11813872.pdf
# Processing CV: 12341902.pdf
# Processing CV: 12674256.pdf
# Processing CV: 14140903.pdf
# Processing CV: 15053703.pdf
# Processing CV: 15546686.pdf
# Processing CV: 15603319.pdf
# Processing CV: 16172429.pdf
# Processing CV: 16507693.pdf
# Processing CV: 16653657.pdf
# Processing CV: 16661264.pdf
# Processing CV: 16849128.pdf
# Processing CV: 17312146.pdf
# Processing CV: 17499196.pdf
# Processing CV: 17640785.pdf
# Processing CV: 18242317.pdf
# Processing CV: 18264694.pdf
# Processing category: APPAREL
# Processing CV: 10182582.pdf
# Processing CV: 10562768.pdf
# Processing CV: 10738095.pdf
# Processing CV: 10876132.pdf
# Processing CV: 11232471.pdf
# Processing CV: 11409460.pdf
# Processing CV: 11677077.pdf
# Processing CV: 12059610.pdf
# Processing CV: 12122372.pdf
# Processing CV: 12668625.pdf
# Processing CV: 12669075.pdf
# Processing CV: 12860543.pdf
# Processing CV: 13386301.pdf
# Processing CV: 13418452.pdf
# Processing CV: 13764840.pdf
# Processing CV: 13807808.pdf
# Processing CV: 13858219.pdf
# Processing CV: 14304010.pdf
# Processing CV: 14413257.pdf
# Processing CV: 14698557.pdf
# Processing category: ARTS
# Processing CV: 10830646.pdf
# Processing CV: 11187796.pdf
# Processing CV: 11360471.pdf
# Processing CV: 11555549.pdf
# Processing CV: 11995013.pdf
# Processing CV: 12334650.pdf
# Processing CV: 12386670.pdf
# Processing CV: 12413512.pdf
# Processing CV: 12777487.pdf
# Processing CV: 13272204.pdf
# Processing CV: 14150896.pdf
# Processing CV: 14248724.pdf
# Processing CV: 14879257.pdf
# Processing CV: 15265464.pdf
# Processing CV: 15306049.pdf
# Processing CV: 16244633.pdf
# Processing CV: 16887936.pdf
# Processing CV: 16962067.pdf
# Processing CV: 17033567.pdf
# Processing CV: 17325147.pdf
# Processing category: AUTOMOBILE
# Processing CV: 11152490.pdf
# Processing CV: 11257723.pdf
# Processing CV: 11797122.pdf
# Processing CV: 11887930.pdf
# Processing CV: 14455622.pdf
# Processing CV: 14508237.pdf
# Processing CV: 15100547.pdf
# Processing CV: 15210069.pdf
# Processing CV: 15484011.pdf
# Processing CV: 15790602.pdf
# Processing CV: 16332293.pdf
# Processing CV: 17510973.pdf
# Processing CV: 17571262.pdf
# Processing CV: 18448085.pdf
# Processing CV: 18932512.pdf
# Processing CV: 22452756.pdf
# Processing CV: 22732234.pdf
# Processing CV: 22946204.pdf
# Processing CV: 23009962.pdf
# Processing CV: 23522150.pdf
# Processing category: AVIATION
# Processing CV: 10176815.pdf
# Processing CV: 10189110.pdf
# Processing CV: 10395944.pdf
# Processing CV: 10567764.pdf
# Processing CV: 10945968.pdf
# Processing CV: 11137306.pdf
# Processing CV: 11169163.pdf
# Processing CV: 11333001.pdf
# Processing CV: 11614114.pdf
# Processing CV: 11752500.pdf
# Processing CV: 11804712.pdf
# Processing CV: 11959428.pdf
# Processing CV: 12043694.pdf
# Processing CV: 12144825.pdf
# Processing CV: 12192507.pdf
# Processing CV: 12239749.pdf
# Processing CV: 12504278.pdf
# Processing CV: 12904972.pdf
# Processing CV: 13195436.pdf
# Processing CV: 13234267.pdf
# Processing category: BANKING
# Processing CV: 10329506.pdf
# Processing CV: 10909673.pdf
# Processing CV: 11065180.pdf
# Processing CV: 11262933.pdf
# Processing CV: 11266906.pdf
# Processing CV: 11637468.pdf
# Processing CV: 11672279.pdf
# Processing CV: 11773925.pdf
# Processing CV: 11842348.pdf
# Processing CV: 12021752.pdf
# Processing CV: 13173522.pdf
# Processing CV: 13393401.pdf
# Processing CV: 13982572.pdf
# Processing CV: 14391434.pdf
# Processing CV: 14626780.pdf
# Processing CV: 15553584.pdf
# Processing CV: 15856762.pdf
# Processing CV: 16300459.pdf
# Processing CV: 16407619.pdf
# Processing CV: 17131084.pdf
# Processing category: BPO
# Processing CV: 11183737.pdf
# Processing CV: 13964744.pdf
# Processing CV: 15145575.pdf
# Processing CV: 15573418.pdf
# Processing CV: 16492045.pdf
# Processing CV: 18589927.pdf
# Processing CV: 19362586.pdf
# Processing CV: 23933031.pdf
# Processing CV: 24727739.pdf
# Processing CV: 26829350.pdf
# Processing CV: 27710853.pdf
# Processing CV: 30709029.pdf
# Processing CV: 31064969.pdf
# Processing CV: 38707449.pdf
# Processing CV: 41152404.pdf
# Processing CV: 45077654.pdf
# Processing CV: 57706851.pdf
# Processing CV: 63158213.pdf
# Processing CV: 69097572.pdf
# Processing CV: 79261033.pdf
# Processing category: BUSINESS-DEVELOPMENT
# Processing CV: 10228751.pdf
# Processing CV: 10235211.pdf
# Processing CV: 10289113.pdf
# Processing CV: 10501991.pdf
# Processing CV: 10541358.pdf
# Processing CV: 10704573.pdf
# Processing CV: 11088337.pdf
# Processing CV: 11289482.pdf
# Processing CV: 11551946.pdf
# Processing CV: 12059198.pdf
# Processing CV: 12230301.pdf
# Processing CV: 12377803.pdf
# Processing CV: 12546838.pdf
# Processing CV: 12632728.pdf
# Processing CV: 12814706.pdf
# Processing CV: 13080868.pdf
# Processing CV: 13199813.pdf
# Processing CV: 13574264.pdf
# Processing CV: 13888506.pdf
# Processing CV: 14055971.pdf
# Processing category: CHEF
# Processing CV: 10001727.pdf
# Processing CV: 10276858.pdf
# Processing CV: 10333299.pdf
# Processing CV: 10588874.pdf
# Processing CV: 10653119.pdf
# Processing CV: 10889157.pdf
# Processing CV: 11121498.pdf
# Processing CV: 11209758.pdf
# Processing CV: 11432686.pdf
# Processing CV: 11444536.pdf
# Processing CV: 12155206.pdf
# Processing CV: 12254068.pdf
# Processing CV: 12420359.pdf
# Processing CV: 12717345.pdf
# Processing CV: 13095891.pdf
# Processing CV: 13212436.pdf
# Processing CV: 13264154.pdf
# Processing CV: 13411858.pdf
# Processing CV: 14569498.pdf
# Processing CV: 14663897.pdf
# Processing category: CONSTRUCTION
# Processing CV: 10041713.pdf
# Processing CV: 10100240.pdf
# Processing CV: 10149490.pdf
# Processing CV: 10176013.pdf
# Processing CV: 10281555.pdf
# Processing CV: 10734870.pdf
# Processing CV: 10820510.pdf
# Processing CV: 11393213.pdf
# Processing CV: 11650031.pdf
# Processing CV: 12212468.pdf
# Processing CV: 12491898.pdf
# Processing CV: 12654876.pdf
# Processing CV: 12666174.pdf
# Processing CV: 12693146.pdf
# Processing CV: 12695537.pdf
# Processing CV: 12826414.pdf
# Processing CV: 12839152.pdf
# Processing CV: 12890045.pdf
# Processing CV: 13907230.pdf
# Processing CV: 14585273.pdf
# Processing category: CONSULTANT
# Processing CV: 10332998.pdf
# Processing CV: 10984392.pdf
# Processing CV: 11020140.pdf
# Processing CV: 11333660.pdf
# Processing CV: 11415967.pdf
# Processing CV: 11835339.pdf
# Processing CV: 12251115.pdf
# Processing CV: 12374933.pdf
# Processing CV: 12526702.pdf
# Processing CV: 12897903.pdf
# Processing CV: 12955994.pdf
# Processing CV: 13215696.pdf
# Processing CV: 13313917.pdf
# Processing CV: 13454871.pdf
# Processing CV: 13569152.pdf
# Processing CV: 13586069.pdf
# Processing CV: 14346702.pdf
# Processing CV: 14517953.pdf
# Processing CV: 14593060.pdf
# Processing CV: 15083600.pdf
# Processing category: DESIGNER
# Processing CV: 10466583.pdf
# Processing CV: 10748989.pdf
# Processing CV: 10751444.pdf
# Processing CV: 11155153.pdf
# Processing CV: 11722421.pdf
# Processing CV: 11807040.pdf
# Processing CV: 11919526.pdf
# Processing CV: 11958994.pdf
# Processing CV: 12415691.pdf
# Processing CV: 12547982.pdf
# Processing CV: 12674307.pdf
# Processing CV: 13014900.pdf
# Processing CV: 13518263.pdf
# Processing CV: 13557622.pdf
# Processing CV: 13774329.pdf
# Processing CV: 13998435.pdf
# Processing CV: 14014749.pdf
# Processing CV: 14528265.pdf
# Processing CV: 14724186.pdf
# Processing CV: 14743911.pdf
# Processing category: DIGITAL-MEDIA
# Processing CV: 10005171.pdf
# Processing CV: 10515955.pdf
# Processing CV: 11005406.pdf
# Processing CV: 11270462.pdf
# Processing CV: 11677012.pdf
# Processing CV: 12085736.pdf
# Processing CV: 13328680.pdf
# Processing CV: 13343786.pdf
# Processing CV: 13503650.pdf
# Processing CV: 13837784.pdf
# Processing CV: 14036515.pdf
# Processing CV: 14209965.pdf
# Processing CV: 14556869.pdf
# Processing CV: 14761906.pdf
# Processing CV: 14771530.pdf
# Processing CV: 14945250.pdf
# Processing CV: 15226699.pdf
# Processing CV: 15353911.pdf
# Processing CV: 15484097.pdf
# Processing CV: 16276121.pdf
# Processing category: ENGINEERING
# Processing CV: 10030015.pdf
# Processing CV: 10219099.pdf
# Processing CV: 10624813.pdf
# Processing CV: 10712803.pdf
# Processing CV: 10985403.pdf
# Processing CV: 11890896.pdf
# Processing CV: 11981094.pdf
# Processing CV: 12011623.pdf
# Processing CV: 12022566.pdf
# Processing CV: 12472574.pdf
# Processing CV: 12488356.pdf
# Processing CV: 12518008.pdf
# Processing CV: 12748557.pdf
# Processing CV: 13149176.pdf
# Processing CV: 13264796.pdf
# Processing CV: 14049846.pdf
# Processing CV: 14206561.pdf
# Processing CV: 14554542.pdf
# Processing CV: 15139979.pdf
# Processing CV: 15601399.pdf
# Processing category: FINANCE
# Processing CV: 10549585.pdf
# Processing CV: 11441764.pdf
# Processing CV: 11490673.pdf
# Processing CV: 11877150.pdf
# Processing CV: 12071138.pdf
# Processing CV: 12858898.pdf
# Processing CV: 14106638.pdf
# Processing CV: 14181049.pdf
# Processing CV: 14408510.pdf
# Processing CV: 14413148.pdf
# Processing CV: 14722634.pdf
# Processing CV: 15011085.pdf
# Processing CV: 15224503.pdf
# Processing CV: 15717923.pdf
# Processing CV: 15792052.pdf
# Processing CV: 15891494.pdf
# Processing CV: 16426777.pdf
# Processing CV: 16449850.pdf
# Processing CV: 17392859.pdf
# Processing CV: 17775916.pdf
# Processing category: FITNESS
# Processing CV: 10235429.pdf
# Processing CV: 10268614.pdf
# Processing CV: 10333051.pdf
# Processing CV: 10428916.pdf
# Processing CV: 10568350.pdf
# Processing CV: 10816645.pdf
# Processing CV: 10969918.pdf
# Processing CV: 11130200.pdf
# Processing CV: 11332602.pdf
# Processing CV: 11522068.pdf
# Processing CV: 12019284.pdf
# Processing CV: 12092347.pdf
# Processing CV: 12695799.pdf
# Processing CV: 12791244.pdf
# Processing CV: 12923795.pdf
# Processing CV: 12938389.pdf
# Processing CV: 13037145.pdf
# Processing CV: 13367322.pdf
# Processing CV: 13675377.pdf
# Processing CV: 14107571.pdf
# Processing category: HEALTHCARE
# Processing CV: 10062724.pdf
# Processing CV: 10076271.pdf
# Processing CV: 10251432.pdf
# Processing CV: 10466208.pdf
# Processing CV: 10480456.pdf
# Processing CV: 10568183.pdf
# Processing CV: 11378657.pdf
# Processing CV: 11605833.pdf
# Processing CV: 11653906.pdf
# Processing CV: 11704150.pdf
# Processing CV: 12315079.pdf
# Processing CV: 12333703.pdf
# Processing CV: 12613221.pdf
# Processing CV: 12938200.pdf
# Processing CV: 13352113.pdf
# Processing CV: 13565152.pdf
# Processing CV: 13575312.pdf
# Processing CV: 14062078.pdf
# Processing CV: 14667957.pdf
# Processing CV: 15499825.pdf
# Processing category: HR
# Processing CV: 10399912.pdf
# Processing CV: 10694288.pdf
# Processing CV: 11480899.pdf
# Processing CV: 11592605.pdf
# Processing CV: 11698189.pdf
# Processing CV: 11763983.pdf
# Processing CV: 11847784.pdf
# Processing CV: 12786012.pdf
# Processing CV: 13376919.pdf
# Processing CV: 13520837.pdf
# Processing CV: 13879043.pdf
# Processing CV: 14225422.pdf
# Processing CV: 14256329.pdf
# Processing CV: 14640322.pdf
# Processing CV: 14886205.pdf
# Processing CV: 15041689.pdf
# Processing CV: 15375009.pdf
# Processing CV: 15575117.pdf
# Processing CV: 15576950.pdf
# Processing CV: 16852973.pdf
# Processing category: INFORMATION-TECHNOLOGY
# Processing CV: 10089434.pdf
# Processing CV: 10247517.pdf
# Processing CV: 10265057.pdf
# Processing CV: 10553553.pdf
# Processing CV: 10641230.pdf
# Processing CV: 10839851.pdf
# Processing CV: 10840430.pdf
# Processing CV: 11580408.pdf
# Processing CV: 11584809.pdf
# Processing CV: 11957080.pdf
# Processing CV: 12045067.pdf
# Processing CV: 12334140.pdf
# Processing CV: 12635195.pdf
# Processing CV: 12763627.pdf
# Processing CV: 13385306.pdf
# Processing CV: 13405733.pdf
# Processing CV: 13477922.pdf
# Processing CV: 13836471.pdf
# Processing CV: 14789139.pdf
# Processing CV: 15118506.pdf
# Processing category: PUBLIC-RELATIONS
# Processing CV: 10070224.pdf
# Processing CV: 10554045.pdf
# Processing CV: 10873344.pdf
# Processing CV: 10926726.pdf
# Processing CV: 11160414.pdf
# Processing CV: 11624880.pdf
# Processing CV: 11635137.pdf
# Processing CV: 11842274.pdf
# Processing CV: 11850315.pdf
# Processing CV: 11902276.pdf
# Processing CV: 12191094.pdf
# Processing CV: 12237267.pdf
# Processing CV: 12545844.pdf
# Processing CV: 12567516.pdf
# Processing CV: 12920612.pdf
# Processing CV: 13129275.pdf
# Processing CV: 13727873.pdf
# Processing CV: 13915715.pdf
# Processing CV: 14009087.pdf
# Processing CV: 14128006.pdf
# Processing category: SALES
# Processing CV: 10138632.pdf
# Processing CV: 10464113.pdf
# Processing CV: 10603337.pdf
# Processing CV: 10724818.pdf
# Processing CV: 10898339.pdf
# Processing CV: 12082377.pdf
# Processing CV: 12351749.pdf
# Processing CV: 12696104.pdf
# Processing CV: 12820557.pdf
# Processing CV: 13178604.pdf
# Processing CV: 13348915.pdf
# Processing CV: 13637605.pdf
# Processing CV: 13812481.pdf
# Processing CV: 14267489.pdf
# Processing CV: 14358578.pdf
# Processing CV: 14381464.pdf
# Processing CV: 15273850.pdf
# Processing CV: 15581242.pdf
# Processing CV: 15620421.pdf
# Processing CV: 15765660.pdf
# Processing category: TEACHER
# Processing CV: 10504237.pdf
# Processing CV: 10527994.pdf
# Processing CV: 10909720.pdf
# Processing CV: 11336022.pdf
# Processing CV: 11616482.pdf
# Processing CV: 11943065.pdf
# Processing CV: 12467531.pdf
# Processing CV: 12587973.pdf
# Processing CV: 13087952.pdf
# Processing CV: 13296856.pdf
# Processing CV: 13330982.pdf
# Processing CV: 13583538.pdf
# Processing CV: 13855004.pdf
# Processing CV: 14958913.pdf
# Processing CV: 15850434.pdf
# Processing CV: 15899269.pdf
# Processing CV: 16210888.pdf
# Processing CV: 16270906.pdf
# Processing CV: 16820422.pdf
# Processing CV: 17311685.pdf

# %%
def verify_database():
    conn = mysql.connector.connect(
        host='ats-database-fareltaza35-4318.b.aivencloud.com',
        user='avnadmin',
        password='AVNS_wk8smk5E9W1DPhrWb3D',
        database='defaultdb',
        port=24585
    )
    cursor = conn.cursor()

    print("\n--- Applicants ---")
    cursor.execute('SELECT * FROM applicantprofile')
    applicants = cursor.fetchall()
    for applicant in applicants:
        print(applicant)

    print("\n--- Applications ---")
    cursor.execute('SELECT * FROM applicationdetail')
    applications = cursor.fetchall()
    for application in applications:
        print(application)

    conn.close()

verify_database()
# Out:
# --- Applicants ---
# (1, 'David', 'Martinez', datetime.date(1971, 11, 15), '19669 Eugene Forge, Porterchester, WY 93566', '(933)894-7108x012')
# (2, 'Asep', 'Suherman', datetime.date(2001, 12, 24), '9429 Tracy Harbor, Meghanside, AZ 94870', '755.499.4125x4553')
# (3, 'Michael', 'Williams', datetime.date(1970, 5, 6), '96841 Adam Pine, Glennbury, VA 33711', '942-226-3363')
# (4, 'Sara', 'Saepuloh', datetime.date(1967, 5, 16), '543 Michelle Keys, Port Brittneybury, NE 76973', '0017649938349')
# (5, 'Jane', 'Martinez', datetime.date(1985, 5, 10), '8491 Lutz Terrace, New Mariashire, NE 09019', '575656341465838')
# (6, 'Asep', 'Sumarna', datetime.date(1964, 12, 21), '17000 Rodriguez Roads, New Erinland, SD 70820', '744766708492339')
# (7, 'Jajang', 'Suherman', datetime.date(2001, 10, 11), '20291 Jennifer Dale, Ryanburgh, WA 66253', '+19368274385205')
# (8, 'Jajang', 'Johnson', datetime.date(2005, 6, 8), '03965 Brenda Isle, East Anthony, VI 16415', '+1259265086746885')
# (9, 'Jajang', 'Davis', datetime.date(1979, 6, 11), '24469 Jeffrey Glen Suite 271, Schmidtmouth, IN 98445', '0016303727620')
# (10, 'Emily', 'Saepuloh', datetime.date(1991, 12, 10), '6442 Johnson Drive, Roberttown, SC 64317', '9246639142')
# (11, 'Katie', 'Williams', datetime.date(1970, 8, 19), '01611 Haley Dam, Kathleenstad, MT 98826', '6533640486')
# (12, 'Supri', 'Saepuloh', datetime.date(1980, 5, 23), '5879 Kimberly Lane Apt. 391, Weissville, RI 66398', '4446806085')
# (13, 'David', 'Santosa', datetime.date(2003, 11, 3), '078 James Ville, Moralesfort, MO 27272', '9959018980')
# (14, 'Katie', 'Jones', datetime.date(1995, 8, 3), '6651 Black Gateway, Nathanielborough, NM 48917', '001368984508767545')
# (15, 'Michael', 'Sumarna', datetime.date(2000, 6, 15), '5288 Richardson Forks, Lake Lisa, CO 22571', '9623086078')
# (16, 'David', 'Hernandez', datetime.date(1988, 6, 7), '36388 Thomas Vista Apt. 680, Lake Susan, TN 62148', '78844423170375')
# (17, 'Katie', 'Sumarna', datetime.date(1991, 10, 19), '56694 Michael Island, West Sheilamouth, AK 07250', '52150828583323')
# (18, 'Alex', 'Martinez', datetime.date(1977, 12, 5), '661 Renee Plaza, Lake Natalie, RI 62147', '4017614477')
# (19, 'Katie', 'Brown', datetime.date(1965, 11, 10), '55151 James Drives, Jacksonview, IL 58196', '9953412191678')
# (20, 'Asep', 'Brown', datetime.date(1966, 7, 30), '55451 Brown Run Suite 340, Rodneyland, VA 75615', '28326965614214')
# (21, 'John', 'Miller', datetime.date(1990, 3, 3), '8262 Jeffrey Summit Suite 376, Port Krystalstad, WY 94935', '804783899721437')
# (22, 'Sara', 'Hernandez', datetime.date(1997, 4, 11), '792 Dorothy Ways Apt. 204, Chandlerstad, WI 85795', '5328948125')
# (23, 'Asep', 'Garcia', datetime.date(1992, 12, 18), '26565 King Junctions Suite 987, Lake Carolinetown, SD 99464', '7762395297')
# (24, 'John', 'Martinez', datetime.date(1973, 2, 23), '2366 Davis Vista Suite 521, North Rachel, CT 67706', '84274155442811')
# (25, 'Dadang', 'Smith', datetime.date(1996, 3, 21), '963 Brandon Squares Apt. 105, West Ashleyborough, CT 63172', '65157173608104')
# (26, 'Alex', 'Santosa', datetime.date(1985, 1, 31), '26230 Amy Mission Apt. 569, Stevenport, KS 98597', '7105513352')
# (27, 'Alex', 'Williams', datetime.date(1992, 11, 13), 'PSC 3144, Box 0134, APO AE 37683', '85479468415234')
# (28, 'Michael', 'Miller', datetime.date(1973, 9, 20), '66626 Marisa Plaza, Jesusville, MO 70383', '9562160660')
# (29, 'John', 'Jones', datetime.date(1990, 3, 24), 'USNS Hale, FPO AP 87095', '5898311826')
# (30, 'Michael', 'Jones', datetime.date(2004, 12, 3), '96342 Sutton Keys Suite 285, West Joel, MP 58820', '5128626693')
# (31, 'Michael', 'Davis', datetime.date(1977, 6, 6), 'Unit 5755 Box 9551, DPO AE 21505', '388430152213971')
# (32, 'Jane', 'Smith', datetime.date(2006, 6, 1), '8154 Kent Court Suite 611, Maldonadoburgh, ND 28050', '8116650778')
# (33, 'Michael', 'Suherman', datetime.date(2003, 2, 27), '3392 Perez Creek Apt. 078, Torresborough, CT 01533', '3677243380')
# (34, 'Jane', 'Sumarna', datetime.date(1976, 3, 1), '577 Ashley Plains Suite 414, Hughesshire, CA 55930', '71097992112288')
# (35, 'Laura', 'Hernandez', datetime.date(1974, 3, 11), '33411 Jacqueline Flat, North Robertfurt, CA 29716', '0013908836172519')
# (36, 'Emily', 'Jones', datetime.date(1993, 9, 23), '3998 Santiago Vista, South Matthewchester, WA 79390', '3006607474')
# (37, 'Asep', 'Davis', datetime.date(2004, 11, 11), '283 Andrews Neck, Flemingchester, MO 84931', '+15859962870436')
# (38, 'Laura', 'Johnson', datetime.date(1996, 8, 21), '20336 Samuel Bridge Apt. 221, West Brittany, DE 68495', '4256995967')
# (39, 'Supri', 'Smith', datetime.date(1977, 3, 7), 'PSC 2031, Box 1540, APO AP 65808', '+1856526330409313')
# (40, 'Katie', 'Santosa', datetime.date(2001, 4, 10), '15854 Angela Port, North Chloehaven, MO 37000', '691304844864962')
# (41, 'Jane', 'Brown', datetime.date(1998, 10, 15), '128 Meadows Plain, North William, IN 63802', '25258322230369')
# (42, 'Jane', 'Williams', datetime.date(1999, 6, 20), '422 Burke Ranch Apt. 698, West Kelly, WV 00952', '0016175954235448')
# (43, 'John', 'Santosa', datetime.date(2000, 11, 14), '20180 Aguilar Path, Port Laurachester, MA 44466', '91062335237486')
# (44, 'Jane', 'Santosa', datetime.date(1993, 12, 9), '4305 Lawrence Ports Apt. 918, Smithmouth, PW 58910', '21575892417587')
# (45, 'Dadang', 'Santosa', datetime.date(1992, 3, 12), '4905 Tucker Lakes, Bennettburgh, GU 43494', '887233599365937')
# (46, 'Jajang', 'Hernandez', datetime.date(2000, 10, 3), '534 Galvan Landing, Riverastad, NH 87485', '6718490538')
# (47, 'John', 'Johnson', datetime.date(1991, 10, 20), '885 Oliver Station, Aaronfort, ND 32387', '0018778676574434')
# (48, 'David', 'Johnson', datetime.date(1978, 12, 25), 'Unit 7216 Box 4808, DPO AE 20507', '416987180929308')
# (49, 'Chris', 'Jones', datetime.date(1966, 12, 13), '8142 Kristopher Islands, Derekborough, VI 01073', '3778811222')
# (50, 'Emily', 'Martinez', datetime.date(1964, 7, 5), '787 Hernandez Cliff, North Donnahaven, IN 43234', '6954981588497')
# (51, 'Emily', 'Williams', datetime.date(1983, 3, 17), '265 Grant Pines Suite 226, Ricebury, MD 81455', '935882415303367')
# (52, 'Emily', 'Brown', datetime.date(1976, 7, 13), '6581 Haynes Walk Apt. 619, North Elizabethmouth, PA 00997', '00139737755425129')
# (53, 'Alex', 'Sumarna', datetime.date(1975, 2, 15), '56441 Brown Heights, Vazquezmouth, WA 55442', '6808898600')
# (54, 'Katie', 'Suherman', datetime.date(1972, 12, 29), '6095 Dean Flat, Williamsshire, OK 95496', '9245311457')
# (55, 'Sara', 'Johnson', datetime.date(2005, 3, 3), '399 Micheal Field, Michaelmouth, ME 38426', '001616938730810536')
# (56, 'Jane', 'Garcia', datetime.date(1984, 10, 25), '978 Joseph Avenue Suite 965, Port Brianchester, AL 11015', '6552137629748')
# (57, 'David', 'Smith', datetime.date(1974, 6, 30), '07741 Christine Plain Apt. 745, Johnsside, FL 78285', '00185761908319862')
# (58, 'Katie', 'Hernandez', datetime.date(1964, 8, 9), '261 Garcia Fork, Robertostad, LA 41577', '2058071119228')
# (59, 'David', 'Saepuloh', datetime.date(1998, 6, 18), '5172 Jeffrey Knoll Suite 904, Julialand, PR 89873', '7185479836939')
# (60, 'Chris', 'Smith', datetime.date(1980, 12, 9), '857 Marshall Tunnel, Johnnyhaven, NJ 44820', '9225286842830')
# (61, 'David', 'Garcia', datetime.date(1992, 9, 9), '55737 Lewis Loop Suite 509, Shannonborough, MH 32673', '8968681207')
# (62, 'Emily', 'Santosa', datetime.date(2002, 11, 26), '56758 Adams Roads Suite 663, Laurieville, MS 63276', '40474898851872')
# (63, 'Supri', 'Garcia', datetime.date(1995, 2, 5), '8784 Shannon Skyway Suite 825, East Jacobville, TN 98527', '0012556244172')
# (64, 'Sara', 'Sumarna', datetime.date(1976, 3, 28), '408 Brad Fords Suite 223, Mirandaville, OK 98003', '8995443371')
# (65, 'Jajang', 'Garcia', datetime.date(1967, 11, 16), '7325 Graham Rapids Apt. 130, East Noahmouth, IN 01497', '+17653214773')
# (66, 'Alex', 'Jones', datetime.date(1976, 10, 3), '18073 Stark Summit Apt. 553, New Joel, SC 91471', '49194986109073')
# (67, 'Sara', 'Miller', datetime.date(1979, 12, 29), '29324 Sean Skyway Apt. 252, Janetshire, WY 20793', '0013963212166')
# (68, 'Supri', 'Johnson', datetime.date(1981, 12, 13), 'PSC 8792, Box 6872, APO AA 78777', '+1967945131479419')
# (69, 'David', 'Davis', datetime.date(1970, 5, 18), 'PSC 2654, Box 0297, APO AP 56201', '3942755303')
# (70, 'Katie', 'Miller', datetime.date(1983, 11, 1), 'PSC 3850, Box 8848, APO AE 28136', '0015487207482')
# (71, 'Jajang', 'Miller', datetime.date(1984, 8, 22), '226 Kimberly Inlet, Alicemouth, MS 04214', '+13309643001787')
# (72, 'Dadang', 'Brown', datetime.date(1989, 11, 5), '6682 Jeffery Circles, New Tarafurt, VI 88809', '7557262922069')
# (73, 'Sara', 'Garcia', datetime.date(1991, 9, 7), '4653 Fowler Lane, South Blakeside, NH 26882', '8348731539')
# (74, 'Dadang', 'Garcia', datetime.date(1985, 9, 6), 'PSC 4925, Box 0529, APO AE 61306', '4268426315242')
# (75, 'Katie', 'Davis', datetime.date(2002, 3, 17), '3015 Jerry Spurs, Gentryfort, ME 24695', '7595367893')
# (76, 'Dadang', 'Hernandez', datetime.date(1990, 7, 19), '617 Amber Fork, West James, AL 96138', '659475117548217')
# (77, 'Emily', 'Smith', datetime.date(1967, 7, 29), 'Unit 1779 Box 9526, DPO AA 60255', '7344528313')
# (78, 'Katie', 'Garcia', datetime.date(1976, 8, 5), '104 Franco Street, Brownhaven, VI 92615', '487944960147300')
# (79, 'Sara', 'Davis', datetime.date(1980, 6, 16), '002 Parker Coves Apt. 236, Helenmouth, ND 95236', '2293392837859')
# (80, 'Jane', 'Miller', datetime.date(1998, 5, 6), '314 Shirley Street, New Deborah, AZ 82120', '+13745224691742')
# (81, 'Chris', 'Davis', datetime.date(1992, 1, 26), '4610 Logan Fall, Parkerhaven, PA 52490', '6658354613')
# (82, 'Laura', 'Brown', datetime.date(1990, 3, 9), '643 Anderson Walks Suite 603, Jonathanberg, OK 25741', '+19945407686')
# (83, 'Laura', 'Davis', datetime.date(1987, 8, 14), '93751 Amy Plains, New Steven, DC 76712', '2546587224311')
# (84, 'Chris', 'Brown', datetime.date(2006, 7, 16), '086 Christina Wall Apt. 706, West Loriton, OK 03390', '2017572048')
# (85, 'John', 'Williams', datetime.date(1983, 11, 20), '9676 Wallace Crescent Suite 457, East Robinhaven, WY 76034', '+1207888106471106')
# (86, 'Asep', 'Smith', datetime.date(1970, 8, 27), '4318 Matthew Radial Suite 856, Moodyborough, DE 49224', '+12903816273421')
# (87, 'Michael', 'Martinez', datetime.date(1991, 4, 13), '75015 Crawford Skyway Apt. 365, North Alexandria, MT 42840', '3445606850')
# (88, 'Dadang', 'Johnson', datetime.date(1998, 9, 25), '30854 Summers Corners Suite 383, North Justinmouth, IN 03670', '9095592233')
# (89, 'Supri', 'Santosa', datetime.date(1977, 9, 2), '854 Erika Lane, Port Shawnbury, OK 69720', '00154163690668436')
# (90, 'John', 'Brown', datetime.date(1965, 9, 5), '40513 Rhonda Camp Suite 648, Grahamport, NE 85648', '55983077165533')
# (91, 'John', 'Smith', datetime.date(2005, 7, 26), '282 Melanie Locks Suite 430, Lake Rachel, OH 23778', '0016338838816')
# (92, 'Chris', 'Suherman', datetime.date(1984, 11, 21), 'USNV Contreras, FPO AP 15861', '32544274869812')
# (93, 'Dadang', 'Sumarna', datetime.date(1970, 10, 15), '8313 Moreno Trail, Hannahfort, WV 27932', '79237809689120')
# (94, 'Dadang', 'Suherman', datetime.date(1965, 11, 17), '707 Jacobs Island Suite 666, Baldwinbury, NE 15910', '285418050436323')
# (95, 'Chris', 'Garcia', datetime.date(2004, 6, 28), '439 Wendy Shores, West Amy, AK 12977', '21930451706340')
# (96, 'Asep', 'Johnson', datetime.date(1998, 12, 22), '7182 Holmes Path, Harrisville, MH 32100', '6503524857159')
# (97, 'Jane', 'Davis', datetime.date(1993, 9, 6), 'USCGC Barber, FPO AE 13480', '0012312386755')
# (98, 'Emily', 'Sumarna', datetime.date(1980, 11, 6), '0257 Alexis Coves Apt. 405, Margaretshire, ME 05994', '7309538058')
# (99, 'Jane', 'Hernandez', datetime.date(2006, 5, 29), '38183 Emily Views, Patriciatown, GA 24028', '+18758918912')
# (100, 'Emily', 'Davis', datetime.date(1978, 12, 9), '39271 Cross Bridge Suite 479, Elizabethville, KY 39517', '4444871051')
# (101, 'John', 'Sumarna', datetime.date(1974, 9, 21), '74353 Katherine Roads, Pamelastad, DE 24462', '7057209512')
# (102, 'Laura', 'Jones', datetime.date(2003, 3, 28), '5087 Hudson Divide, Lake Karenshire, NY 11940', '666634559170339')
# (103, 'Alex', 'Davis', datetime.date(1971, 7, 3), '52655 Hayes Mount Suite 072, Warrenhaven, UT 00509', '3779646575')
# (104, 'Laura', 'Williams', datetime.date(1979, 1, 14), '0919 Stone Causeway Apt. 616, Jennifermouth, WV 16631', '+12944249582')
# (105, 'David', 'Jones', datetime.date(1999, 7, 4), '466 Long Crescent Suite 912, North Maryton, KS 96016', '00143230097645054')
# (106, 'Jajang', 'Saepuloh', datetime.date(1967, 9, 21), '11715 Browning Centers, Montgomerybury, AK 70704', '+12466845125496')
# (107, 'Katie', 'Johnson', datetime.date(1999, 6, 8), '501 Bright Rest Suite 106, North Dennismouth, WY 30234', '5238632733187')
# (108, 'Katie', 'Smith', datetime.date(1973, 11, 15), '93328 Melissa Stream Apt. 858, West Carlos, KY 35751', '+194520102066478')
# (109, 'Alex', 'Johnson', datetime.date(1973, 12, 27), '777 Kenneth Greens, Carmenland, NJ 89553', '31939546222479')
# (110, 'Cecep', 'Santosa', datetime.date(1970, 6, 1), 'Unit 2914 Box 1300, DPO AE 88849', '53371948123575')
# (111, 'Asep', 'Miller', datetime.date(1977, 1, 3), '67376 Jesus Path Apt. 818, West Taylor, TN 87232', '2432446120')
# (112, 'Jajang', 'Martinez', datetime.date(1976, 2, 19), '7649 Chandler Highway Apt. 367, Michaelchester, MA 60565', '001607652144575069')
# (113, 'Alex', 'Brown', datetime.date(1970, 10, 20), '8869 Bryan Union Apt. 955, Changview, MH 83116', '5378248929')
# (114, 'Michael', 'Santosa', datetime.date(1971, 6, 22), '00158 Rachel Stravenue, East Jenniferside, MO 04555', '001406659472780132')
# (115, 'Cecep', 'Hernandez', datetime.date(1966, 5, 30), '002 Watson Land Suite 609, New Jesus, WV 86376', '9255443539615')
# (116, 'Katie', 'Saepuloh', datetime.date(1990, 9, 7), '08923 Hall Key Suite 843, South Claudia, MA 35224', '2389630374942')
# (117, 'Emily', 'Johnson', datetime.date(1973, 8, 27), '25326 Brenda Walk Apt. 498, New Robynbury, NE 65064', '5406102887')
# (118, 'Chris', 'Hernandez', datetime.date(1994, 3, 22), '9777 Emily Mill Suite 734, Michaelchester, WI 95506', '96239733561300')
# (119, 'Asep', 'Williams', datetime.date(1999, 2, 7), '32052 Emily Centers, Lake Nicholasport, VI 07978', '3465452794')
# (120, 'Cecep', 'Sumarna', datetime.date(1981, 2, 25), '49575 Moody Meadows, Andrewport, ME 95713', '3359248894')
# (121, 'David', 'Suherman', datetime.date(1981, 9, 1), '812 Mitchell Roads Suite 062, Tinamouth, ID 64924', '+1802282863834611')
# (122, 'Dadang', 'Davis', datetime.date(1968, 1, 13), '19739 Dickson Road Apt. 790, East Anthony, GA 97364', '55978169625636')
# (123, 'Cecep', 'Suherman', datetime.date(1999, 10, 10), '11487 Darren Turnpike Apt. 373, Lake Ianchester, MD 02839', '956993144091712')
# (124, 'Cecep', 'Martinez', datetime.date(1969, 2, 14), '047 Gallegos Camp, Newtonville, ND 73070', '0016272979388')
# (125, 'Dadang', 'Williams', datetime.date(1975, 1, 5), '99711 Heidi Run, Williamstown, OH 42782', '8307279381')
# (126, 'David', 'Williams', datetime.date(1989, 10, 3), '8734 Owen Knolls, New Josephberg, ND 67482', '6448329640283')
# (127, 'Dadang', 'Martinez', datetime.date(1997, 3, 25), '138 Martin Knolls, East Aaronmouth, CT 97047', '4295256115943')
# (128, 'Supri', 'Suherman', datetime.date(1971, 6, 24), '4049 Murphy Island Apt. 803, Bakerbury, NY 61200', '8865306550')
# (129, 'Cecep', 'Williams', datetime.date(2002, 3, 2), '0647 Page Greens, Greenfort, AL 55559', '+18902213939282')
# (130, 'Supri', 'Williams', datetime.date(2003, 1, 7), '319 Justin Prairie, South Joseph, PW 20919', '5257855584')
# (131, 'Laura', 'Saepuloh', datetime.date(1974, 7, 29), '76041 Donald Cove Suite 117, East Timothymouth, HI 76888', '730975665914007')
# (132, 'Chris', 'Miller', datetime.date(1985, 5, 9), '6402 Leslie Mission, Potterstad, AL 77551', '+1340728301268401')
# (133, 'Sara', 'Smith', datetime.date(1972, 12, 9), '21788 Banks Greens Suite 725, Rogersberg, VI 19187', '6133066291128')
# (134, 'Dadang', 'Jones', datetime.date(1985, 1, 24), '09288 George Haven Suite 459, Judithfurt, AZ 08568', '+14434599266')
# (135, 'Jane', 'Johnson', datetime.date(1992, 12, 18), 'USNV Beck, FPO AP 69001', '883850489548228')
# (136, 'Michael', 'Hernandez', datetime.date(1979, 3, 8), '49624 Jones Skyway, Port Nicole, GA 51202', '5714575396')
# (137, 'Emily', 'Miller', datetime.date(1982, 5, 17), '1148 Shelley Motorway Suite 732, Solomonville, SD 02304', '+167986902350371')
# (138, 'Jane', 'Jones', datetime.date(2001, 6, 2), '1428 Alyssa Spring, East Leah, MP 15769', '+17606484468068')
# (139, 'John', 'Davis', datetime.date(2006, 7, 8), '09379 Fernando Village, Michaelhaven, OH 42760', '+1244737714478870')
# (140, 'Asep', 'Saepuloh', datetime.date(1998, 12, 6), '350 Martin Stream, South April, DE 04881', '3035017794')
# (141, 'Alex', 'Hernandez', datetime.date(2000, 10, 31), '463 Davis Creek Apt. 682, Shannonport, IA 11380', '4828169650')
# (142, 'Alex', 'Smith', datetime.date(1988, 12, 3), '97064 Perez Spring Suite 571, South Blake, WI 24699', '3176914074')
# (143, 'Dadang', 'Miller', datetime.date(1985, 8, 22), '4982 West Courts Suite 977, North Laura, NH 41932', '6669290573')
# (144, 'Jajang', 'Smith', datetime.date(1975, 9, 16), '8241 Justin Underpass Suite 409, Tinaland, SC 34494', '+17123087760')
# (145, 'Jajang', 'Sumarna', datetime.date(2002, 9, 4), '993 Cannon Meadow, Gillhaven, MH 50830', '8638466832')
# (146, 'Sara', 'Brown', datetime.date(2002, 5, 7), '720 Arnold Greens, Port Wendy, VI 19098', '+191233213709272')
# (147, 'Chris', 'Johnson', datetime.date(1979, 7, 8), '1558 Thomas Prairie, Lake Jennifer, VA 05143', '5627120144')
# (148, 'Cecep', 'Brown', datetime.date(1974, 12, 22), '785 Randy Mews Suite 587, Youngbury, HI 94291', '00188923847467467')
# (149, 'Katie', 'Martinez', datetime.date(1978, 4, 15), '14061 Hill Square Suite 630, Clairefort, WY 34025', '2446901740188')
# (150, 'Emily', 'Garcia', datetime.date(2003, 3, 29), '6652 Morris Pines Suite 174, East Morgan, GU 62843', '699818317857977')
# (151, 'Supri', 'Brown', datetime.date(1990, 6, 25), '660 Vernon Flat Suite 718, Lake Cassandrashire, ID 31394', '82989457034763')
# (152, 'Laura', 'Suherman', datetime.date(1966, 7, 25), 'USNV Yang, FPO AA 95541', '0013898957799')
# (153, 'Jane', 'Saepuloh', datetime.date(2006, 9, 21), '5705 Hobbs Route Suite 406, Dunlaptown, VA 47143', '979720746873219')
# (154, 'Supri', 'Miller', datetime.date(1990, 4, 19), '246 Brittany Valleys, North Jamieshire, GA 82407', '509442737613277')
# (155, 'Supri', 'Sumarna', datetime.date(1990, 11, 1), '85683 Mccullough Ferry, Hernandezchester, SC 06845', '562962765220475')
# (156, 'Jajang', 'Brown', datetime.date(2006, 2, 3), '67127 Ruiz Run Suite 548, New Earlmouth, HI 01319', '+13952195284')
# (157, 'Cecep', 'Davis', datetime.date(1979, 10, 9), '130 Brandi Coves Apt. 258, Kaylaburgh, MP 43616', '+18663556504267')
# (158, 'Michael', 'Garcia', datetime.date(1965, 12, 10), '061 Taylor Courts Apt. 037, Kellyhaven, IL 01412', '3867886074286')
# (159, 'Supri', 'Martinez', datetime.date(1965, 8, 3), '5459 Bentley Corner Apt. 547, West Nicole, CA 13762', '89557751815042')
# (160, 'Laura', 'Santosa', datetime.date(1966, 8, 22), '9839 James Glens Suite 974, Bowersland, CA 73931', '976214493646360')
# (161, 'Laura', 'Sumarna', datetime.date(2006, 10, 3), '720 Michael Summit, Port Morganhaven, AS 84783', '6389813535326')
# (162, 'Chris', 'Martinez', datetime.date(1999, 7, 21), '258 Wilson Mission, Port Toddstad, MD 63942', '43532135583923')
# (163, 'Michael', 'Johnson', datetime.date(1989, 10, 3), '4394 Pineda Glens, North Deborah, NY 28520', '5374912199')
# (164, 'Supri', 'Hernandez', datetime.date(1980, 3, 11), '7307 Roberson Mews, Leehaven, SD 83793', '7987916058793')
# (165, 'John', 'Saepuloh', datetime.date(2002, 6, 18), '759 Anna Pine, Reynoldsfort, RI 44795', '+16784163379089')
# (166, 'Laura', 'Miller', datetime.date(1996, 5, 29), '332 Gonzalez Valleys Apt. 433, East Travischester, NJ 82825', '2197069077')
# (167, 'Michael', 'Saepuloh', datetime.date(1980, 3, 8), '01811 Roberson Fields Apt. 301, South Johnfort, UT 18574', '2622896298813')
# (168, 'Emily', 'Suherman', datetime.date(1965, 11, 7), '14842 Julie Roads, Gabrielleville, ID 95109', '2135198241')
# (169, 'Sara', 'Williams', datetime.date(1985, 5, 7), '33105 Barry Harbors, New Jacquelineside, PW 41521', '71144762783823')
# (170, 'Asep', 'Jones', datetime.date(1976, 5, 19), '18832 Williams Road, Denniston, ME 52682', '2857592332466')
# (171, 'John', 'Garcia', datetime.date(1967, 9, 9), '85400 Michelle Highway Suite 074, South Michaelview, WA 60572', '+145635317820624')
# (172, 'Sara', 'Martinez', datetime.date(1964, 8, 15), '103 Sutton Orchard Apt. 036, Cowanberg, ME 08540', '9545178662')
# (173, 'Jajang', 'Jones', datetime.date(2001, 5, 6), '16962 Courtney Parkways Suite 760, Port Russellport, VI 19646', '+16413219588')
# (174, 'Jajang', 'Santosa', datetime.date(1993, 11, 3), '14091 Lisa Crossroad Apt. 628, West Robert, GA 35148', '00188024246725357')
# (175, 'Supri', 'Davis', datetime.date(2002, 12, 9), '9965 Breanna Drive Apt. 488, Lisaburgh, AR 35475', '362745037881678')
# (176, 'Jane', 'Suherman', datetime.date(1994, 11, 24), '42557 Vazquez Station Apt. 963, Santiagoton, OH 75076', '6154071064')
# (177, 'Asep', 'Martinez', datetime.date(1990, 12, 6), '4667 Caitlyn Port, Perezmouth, NJ 23358', '5738600928')
# (178, 'Laura', 'Smith', datetime.date(2005, 12, 12), 'Unit 9958 Box 7706, DPO AP 24945', '+17948690890')
# (179, 'Laura', 'Garcia', datetime.date(1990, 5, 1), '508 Dickerson Centers Suite 406, Dawnburgh, MD 68343', '4623193029')
# (180, 'David', 'Miller', datetime.date(1991, 1, 14), '942 Gomez Inlet, West Krista, ME 53526', '6245657020')
# (181, 'Chris', 'Santosa', datetime.date(1966, 10, 18), '9836 Lisa Springs, Jimenezfurt, IA 60387', '3922047377')
# (182, 'Emily', 'Hernandez', datetime.date(1978, 9, 10), '544 David Manors Apt. 975, Sabrinaburgh, TN 47309', '001582714062789756')
# (183, 'Chris', 'Sumarna', datetime.date(1967, 7, 9), '3936 Leonard Lake Suite 188, Justinmouth, HI 91193', '0012985874315')
# (184, 'Alex', 'Saepuloh', datetime.date(2006, 6, 23), '937 Sutton Rue, North Josephville, HI 84255', '0013644279724167')
# (185, 'Asep', 'Santosa', datetime.date(2006, 7, 9), '615 Matthew Ford, Port Cynthia, UT 39484', '6084571502452')
# (186, 'Laura', 'Martinez', datetime.date(2002, 8, 1), '15372 Myers Cliff, Lake Melanie, ND 95710', '437818331129179')
# (187, 'John', 'Hernandez', datetime.date(1997, 3, 30), '518 Barnes Summit, Joannemouth, FL 27599', '00140442133781697')
# (188, 'Cecep', 'Saepuloh', datetime.date(1964, 11, 17), 'PSC 6075, Box 7467, APO AE 15506', '7635846165')
# (189, 'Supri', 'Jones', datetime.date(1992, 6, 28), '096 Hart Passage, New Rachelview, CT 69243', '8758648488')
#
# --- Applications ---
# (1, 1, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\10554236.pdf')
# (2, 2, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\10674770.pdf')
# (3, 3, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\11163645.pdf')
# (4, 4, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\10554236.pdf')
# (5, 5, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\10674770.pdf')
# (6, 6, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\11163645.pdf')
# (7, 7, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\11759079.pdf')
# (8, 8, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12065211.pdf')
# (9, 1, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12202337.pdf')
# (10, 9, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12338274.pdf')
# (11, 10, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12442909.pdf')
# (12, 11, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12780508.pdf')
# (13, 11, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\12802330.pdf')
# (14, 12, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13072019.pdf')
# (15, 13, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13130984.pdf')
# (16, 14, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13294301.pdf')
# (17, 15, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13491889.pdf')
# (18, 16, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\13701259.pdf')
# (19, 15, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14055988.pdf')
# (20, 17, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14126433.pdf')
# (21, 18, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14224370.pdf')
# (22, 19, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14449423.pdf')
# (23, 13, 'ACCOUNTANT', 'archive\\data\\data\\ACCOUNTANT\\14470533.pdf')
# (24, 20, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10186968.pdf')
# (25, 21, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10344379.pdf')
# (26, 22, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10659182.pdf')
# (27, 23, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\10818478.pdf')
# (28, 24, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11174187.pdf')
# (29, 25, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11188218.pdf')
# (30, 26, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11773767.pdf')
# (31, 27, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\11963737.pdf')
# (32, 17, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\12171093.pdf')
# (33, 28, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\12544735.pdf')
# (34, 29, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13072354.pdf')
# (35, 30, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13115648.pdf')
# (36, 4, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13342150.pdf')
# (37, 31, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13593241.pdf')
# (38, 32, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13809698.pdf')
# (39, 33, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13909762.pdf')
# (40, 34, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\13967854.pdf')
# (41, 9, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\14064815.pdf')
# (42, 35, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\14146106.pdf')
# (43, 36, 'ADVOCATE', 'archive\\data\\data\\ADVOCATE\\14176254.pdf')
# (44, 37, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\10953078.pdf')
# (45, 9, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\11197262.pdf')
# (46, 38, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\11676151.pdf')
# (47, 39, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\11813872.pdf')
# (48, 40, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\12341902.pdf')
# (49, 41, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\12674256.pdf')
# (50, 42, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\14140903.pdf')
# (51, 43, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\15053703.pdf')
# (52, 44, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\15546686.pdf')
# (53, 45, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\15603319.pdf')
# (54, 46, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16172429.pdf')
# (55, 47, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16507693.pdf')
# (56, 48, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16653657.pdf')
# (57, 49, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16661264.pdf')
# (58, 50, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\16849128.pdf')
# (59, 51, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\17312146.pdf')
# (60, 52, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\17499196.pdf')
# (61, 53, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\17640785.pdf')
# (62, 54, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\18242317.pdf')
# (63, 55, 'AGRICULTURE', 'archive\\data\\data\\AGRICULTURE\\18264694.pdf')
# (64, 55, 'APPAREL', 'archive\\data\\data\\APPAREL\\10182582.pdf')
# (65, 7, 'APPAREL', 'archive\\data\\data\\APPAREL\\10562768.pdf')
# (66, 56, 'APPAREL', 'archive\\data\\data\\APPAREL\\10738095.pdf')
# (67, 57, 'APPAREL', 'archive\\data\\data\\APPAREL\\10876132.pdf')
# (68, 58, 'APPAREL', 'archive\\data\\data\\APPAREL\\11232471.pdf')
# (69, 52, 'APPAREL', 'archive\\data\\data\\APPAREL\\11409460.pdf')
# (70, 59, 'APPAREL', 'archive\\data\\data\\APPAREL\\11677077.pdf')
# (71, 42, 'APPAREL', 'archive\\data\\data\\APPAREL\\12059610.pdf')
# (72, 60, 'APPAREL', 'archive\\data\\data\\APPAREL\\12122372.pdf')
# (73, 61, 'APPAREL', 'archive\\data\\data\\APPAREL\\12668625.pdf')
# (74, 62, 'APPAREL', 'archive\\data\\data\\APPAREL\\12669075.pdf')
# (75, 7, 'APPAREL', 'archive\\data\\data\\APPAREL\\12860543.pdf')
# (76, 11, 'APPAREL', 'archive\\data\\data\\APPAREL\\13386301.pdf')
# (77, 35, 'APPAREL', 'archive\\data\\data\\APPAREL\\13418452.pdf')
# (78, 63, 'APPAREL', 'archive\\data\\data\\APPAREL\\13764840.pdf')
# (79, 63, 'APPAREL', 'archive\\data\\data\\APPAREL\\13807808.pdf')
# (80, 62, 'APPAREL', 'archive\\data\\data\\APPAREL\\13858219.pdf')
# (81, 64, 'APPAREL', 'archive\\data\\data\\APPAREL\\14304010.pdf')
# (82, 23, 'APPAREL', 'archive\\data\\data\\APPAREL\\14413257.pdf')
# (83, 65, 'APPAREL', 'archive\\data\\data\\APPAREL\\14698557.pdf')
# (84, 43, 'ARTS', 'archive\\data\\data\\ARTS\\10830646.pdf')
# (85, 66, 'ARTS', 'archive\\data\\data\\ARTS\\11187796.pdf')
# (86, 67, 'ARTS', 'archive\\data\\data\\ARTS\\11360471.pdf')
# (87, 68, 'ARTS', 'archive\\data\\data\\ARTS\\11555549.pdf')
# (88, 21, 'ARTS', 'archive\\data\\data\\ARTS\\11995013.pdf')
# (89, 69, 'ARTS', 'archive\\data\\data\\ARTS\\12334650.pdf')
# (90, 52, 'ARTS', 'archive\\data\\data\\ARTS\\12386670.pdf')
# (91, 46, 'ARTS', 'archive\\data\\data\\ARTS\\12413512.pdf')
# (92, 5, 'ARTS', 'archive\\data\\data\\ARTS\\12777487.pdf')
# (93, 70, 'ARTS', 'archive\\data\\data\\ARTS\\13272204.pdf')
# (94, 71, 'ARTS', 'archive\\data\\data\\ARTS\\14150896.pdf')
# (95, 15, 'ARTS', 'archive\\data\\data\\ARTS\\14248724.pdf')
# (96, 72, 'ARTS', 'archive\\data\\data\\ARTS\\14879257.pdf')
# (97, 73, 'ARTS', 'archive\\data\\data\\ARTS\\15265464.pdf')
# (98, 74, 'ARTS', 'archive\\data\\data\\ARTS\\15306049.pdf')
# (99, 75, 'ARTS', 'archive\\data\\data\\ARTS\\16244633.pdf')
# (100, 76, 'ARTS', 'archive\\data\\data\\ARTS\\16887936.pdf')
# (101, 77, 'ARTS', 'archive\\data\\data\\ARTS\\16962067.pdf')
# (102, 77, 'ARTS', 'archive\\data\\data\\ARTS\\17033567.pdf')
# (103, 78, 'ARTS', 'archive\\data\\data\\ARTS\\17325147.pdf')
# (104, 61, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11152490.pdf')
# (105, 79, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11257723.pdf')
# (106, 80, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11797122.pdf')
# (107, 18, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\11887930.pdf')
# (108, 81, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\14455622.pdf')
# (109, 82, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\14508237.pdf')
# (110, 31, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15100547.pdf')
# (111, 13, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15210069.pdf')
# (112, 49, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15484011.pdf')
# (113, 55, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\15790602.pdf')
# (114, 83, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\16332293.pdf')
# (115, 84, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\17510973.pdf')
# (116, 85, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\17571262.pdf')
# (117, 86, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\18448085.pdf')
# (118, 87, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\18932512.pdf')
# (119, 88, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\22452756.pdf')
# (120, 86, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\22732234.pdf')
# (121, 30, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\22946204.pdf')
# (122, 34, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\23009962.pdf')
# (123, 78, 'AUTOMOBILE', 'archive\\data\\data\\AUTOMOBILE\\23522150.pdf')
# (124, 19, 'AVIATION', 'archive\\data\\data\\AVIATION\\10176815.pdf')
# (125, 89, 'AVIATION', 'archive\\data\\data\\AVIATION\\10189110.pdf')
# (126, 90, 'AVIATION', 'archive\\data\\data\\AVIATION\\10395944.pdf')
# (127, 6, 'AVIATION', 'archive\\data\\data\\AVIATION\\10567764.pdf')
# (128, 91, 'AVIATION', 'archive\\data\\data\\AVIATION\\10945968.pdf')
# (129, 92, 'AVIATION', 'archive\\data\\data\\AVIATION\\11137306.pdf')
# (130, 65, 'AVIATION', 'archive\\data\\data\\AVIATION\\11169163.pdf')
# (131, 93, 'AVIATION', 'archive\\data\\data\\AVIATION\\11333001.pdf')
# (132, 23, 'AVIATION', 'archive\\data\\data\\AVIATION\\11614114.pdf')
# (133, 94, 'AVIATION', 'archive\\data\\data\\AVIATION\\11752500.pdf')
# (134, 35, 'AVIATION', 'archive\\data\\data\\AVIATION\\11804712.pdf')
# (135, 15, 'AVIATION', 'archive\\data\\data\\AVIATION\\11959428.pdf')
# (136, 2, 'AVIATION', 'archive\\data\\data\\AVIATION\\12043694.pdf')
# (137, 95, 'AVIATION', 'archive\\data\\data\\AVIATION\\12144825.pdf')
# (138, 9, 'AVIATION', 'archive\\data\\data\\AVIATION\\12192507.pdf')
# (139, 78, 'AVIATION', 'archive\\data\\data\\AVIATION\\12239749.pdf')
# (140, 44, 'AVIATION', 'archive\\data\\data\\AVIATION\\12504278.pdf')
# (141, 96, 'AVIATION', 'archive\\data\\data\\AVIATION\\12904972.pdf')
# (142, 83, 'AVIATION', 'archive\\data\\data\\AVIATION\\13195436.pdf')
# (143, 59, 'AVIATION', 'archive\\data\\data\\AVIATION\\13234267.pdf')
# (144, 97, 'BANKING', 'archive\\data\\data\\BANKING\\10329506.pdf')
# (145, 68, 'BANKING', 'archive\\data\\data\\BANKING\\10909673.pdf')
# (146, 98, 'BANKING', 'archive\\data\\data\\BANKING\\11065180.pdf')
# (147, 99, 'BANKING', 'archive\\data\\data\\BANKING\\11262933.pdf')
# (148, 100, 'BANKING', 'archive\\data\\data\\BANKING\\11266906.pdf')
# (149, 101, 'BANKING', 'archive\\data\\data\\BANKING\\11637468.pdf')
# (150, 102, 'BANKING', 'archive\\data\\data\\BANKING\\11672279.pdf')
# (151, 83, 'BANKING', 'archive\\data\\data\\BANKING\\11773925.pdf')
# (152, 54, 'BANKING', 'archive\\data\\data\\BANKING\\11842348.pdf')
# (153, 36, 'BANKING', 'archive\\data\\data\\BANKING\\12021752.pdf')
# (154, 87, 'BANKING', 'archive\\data\\data\\BANKING\\13173522.pdf')
# (155, 2, 'BANKING', 'archive\\data\\data\\BANKING\\13393401.pdf')
# (156, 103, 'BANKING', 'archive\\data\\data\\BANKING\\13982572.pdf')
# (157, 104, 'BANKING', 'archive\\data\\data\\BANKING\\14391434.pdf')
# (158, 103, 'BANKING', 'archive\\data\\data\\BANKING\\14626780.pdf')
# (159, 4, 'BANKING', 'archive\\data\\data\\BANKING\\15553584.pdf')
# (160, 105, 'BANKING', 'archive\\data\\data\\BANKING\\15856762.pdf')
# (161, 18, 'BANKING', 'archive\\data\\data\\BANKING\\16300459.pdf')
# (162, 106, 'BANKING', 'archive\\data\\data\\BANKING\\16407619.pdf')
# (163, 107, 'BANKING', 'archive\\data\\data\\BANKING\\17131084.pdf')
# (164, 108, 'BPO', 'archive\\data\\data\\BPO\\11183737.pdf')
# (165, 109, 'BPO', 'archive\\data\\data\\BPO\\13964744.pdf')
# (166, 110, 'BPO', 'archive\\data\\data\\BPO\\15145575.pdf')
# (167, 111, 'BPO', 'archive\\data\\data\\BPO\\15573418.pdf')
# (168, 81, 'BPO', 'archive\\data\\data\\BPO\\16492045.pdf')
# (169, 60, 'BPO', 'archive\\data\\data\\BPO\\18589927.pdf')
# (170, 112, 'BPO', 'archive\\data\\data\\BPO\\19362586.pdf')
# (171, 113, 'BPO', 'archive\\data\\data\\BPO\\23933031.pdf')
# (172, 114, 'BPO', 'archive\\data\\data\\BPO\\24727739.pdf')
# (173, 115, 'BPO', 'archive\\data\\data\\BPO\\26829350.pdf')
# (174, 54, 'BPO', 'archive\\data\\data\\BPO\\27710853.pdf')
# (175, 60, 'BPO', 'archive\\data\\data\\BPO\\30709029.pdf')
# (176, 43, 'BPO', 'archive\\data\\data\\BPO\\31064969.pdf')
# (177, 69, 'BPO', 'archive\\data\\data\\BPO\\38707449.pdf')
# (178, 49, 'BPO', 'archive\\data\\data\\BPO\\41152404.pdf')
# (179, 41, 'BPO', 'archive\\data\\data\\BPO\\45077654.pdf')
# (180, 116, 'BPO', 'archive\\data\\data\\BPO\\57706851.pdf')
# (181, 33, 'BPO', 'archive\\data\\data\\BPO\\63158213.pdf')
# (182, 104, 'BPO', 'archive\\data\\data\\BPO\\69097572.pdf')
# (183, 117, 'BPO', 'archive\\data\\data\\BPO\\79261033.pdf')
# (184, 118, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10228751.pdf')
# (185, 26, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10235211.pdf')
# (186, 119, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10289113.pdf')
# (187, 53, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10501991.pdf')
# (188, 79, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10541358.pdf')
# (189, 57, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\10704573.pdf')
# (190, 120, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\11088337.pdf')
# (191, 117, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\11289482.pdf')
# (192, 121, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\11551946.pdf')
# (193, 66, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12059198.pdf')
# (194, 122, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12230301.pdf')
# (195, 36, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12377803.pdf')
# (196, 80, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12546838.pdf')
# (197, 46, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12632728.pdf')
# (198, 123, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\12814706.pdf')
# (199, 48, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13080868.pdf')
# (200, 124, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13199813.pdf')
# (201, 125, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13574264.pdf')
# (202, 49, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\13888506.pdf')
# (203, 119, 'BUSINESS-DEVELOPMENT', 'archive\\data\\data\\BUSINESS-DEVELOPMENT\\14055971.pdf')
# (204, 77, 'CHEF', 'archive\\data\\data\\CHEF\\10001727.pdf')
# (205, 50, 'CHEF', 'archive\\data\\data\\CHEF\\10276858.pdf')
# (206, 61, 'CHEF', 'archive\\data\\data\\CHEF\\10333299.pdf')
# (207, 73, 'CHEF', 'archive\\data\\data\\CHEF\\10588874.pdf')
# (208, 107, 'CHEF', 'archive\\data\\data\\CHEF\\10653119.pdf')
# (209, 126, 'CHEF', 'archive\\data\\data\\CHEF\\10889157.pdf')
# (210, 127, 'CHEF', 'archive\\data\\data\\CHEF\\11121498.pdf')
# (211, 128, 'CHEF', 'archive\\data\\data\\CHEF\\11209758.pdf')
# (212, 41, 'CHEF', 'archive\\data\\data\\CHEF\\11432686.pdf')
# (213, 129, 'CHEF', 'archive\\data\\data\\CHEF\\11444536.pdf')
# (214, 17, 'CHEF', 'archive\\data\\data\\CHEF\\12155206.pdf')
# (215, 130, 'CHEF', 'archive\\data\\data\\CHEF\\12254068.pdf')
# (216, 131, 'CHEF', 'archive\\data\\data\\CHEF\\12420359.pdf')
# (217, 132, 'CHEF', 'archive\\data\\data\\CHEF\\12717345.pdf')
# (218, 22, 'CHEF', 'archive\\data\\data\\CHEF\\13095891.pdf')
# (219, 47, 'CHEF', 'archive\\data\\data\\CHEF\\13212436.pdf')
# (220, 120, 'CHEF', 'archive\\data\\data\\CHEF\\13264154.pdf')
# (221, 71, 'CHEF', 'archive\\data\\data\\CHEF\\13411858.pdf')
# (222, 133, 'CHEF', 'archive\\data\\data\\CHEF\\14569498.pdf')
# (223, 27, 'CHEF', 'archive\\data\\data\\CHEF\\14663897.pdf')
# (224, 13, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10041713.pdf')
# (225, 134, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10100240.pdf')
# (226, 135, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10149490.pdf')
# (227, 136, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10176013.pdf')
# (228, 12, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10281555.pdf')
# (229, 137, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10734870.pdf')
# (230, 53, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\10820510.pdf')
# (231, 138, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\11393213.pdf')
# (232, 48, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\11650031.pdf')
# (233, 139, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12212468.pdf')
# (234, 40, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12491898.pdf')
# (235, 33, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12654876.pdf')
# (236, 127, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12666174.pdf')
# (237, 140, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12693146.pdf')
# (238, 8, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12695537.pdf')
# (239, 21, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12826414.pdf')
# (240, 114, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12839152.pdf')
# (241, 104, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\12890045.pdf')
# (242, 141, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\13907230.pdf')
# (243, 142, 'CONSTRUCTION', 'archive\\data\\data\\CONSTRUCTION\\14585273.pdf')
# (244, 114, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\10332998.pdf')
# (245, 115, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\10984392.pdf')
# (246, 143, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11020140.pdf')
# (247, 35, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11333660.pdf')
# (248, 144, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11415967.pdf')
# (249, 139, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\11835339.pdf')
# (250, 37, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12251115.pdf')
# (251, 25, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12374933.pdf')
# (252, 145, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12526702.pdf')
# (253, 146, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12897903.pdf')
# (254, 86, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\12955994.pdf')
# (255, 147, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13215696.pdf')
# (256, 40, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13313917.pdf')
# (257, 111, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13454871.pdf')
# (258, 112, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13569152.pdf')
# (259, 57, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\13586069.pdf')
# (260, 127, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\14346702.pdf')
# (261, 148, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\14517953.pdf')
# (262, 119, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\14593060.pdf')
# (263, 114, 'CONSULTANT', 'archive\\data\\data\\CONSULTANT\\15083600.pdf')
# (264, 58, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\10466583.pdf')
# (265, 93, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\10748989.pdf')
# (266, 149, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\10751444.pdf')
# (267, 150, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11155153.pdf')
# (268, 151, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11722421.pdf')
# (269, 41, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11807040.pdf')
# (270, 90, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11919526.pdf')
# (271, 93, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\11958994.pdf')
# (272, 103, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\12415691.pdf')
# (273, 16, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\12547982.pdf')
# (274, 35, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\12674307.pdf')
# (275, 86, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13014900.pdf')
# (276, 35, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13518263.pdf')
# (277, 116, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13557622.pdf')
# (278, 122, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13774329.pdf')
# (279, 152, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\13998435.pdf')
# (280, 17, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14014749.pdf')
# (281, 113, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14528265.pdf')
# (282, 41, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14724186.pdf')
# (283, 28, 'DESIGNER', 'archive\\data\\data\\DESIGNER\\14743911.pdf')
# (284, 130, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\10005171.pdf')
# (285, 37, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\10515955.pdf')
# (286, 71, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\11005406.pdf')
# (287, 153, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\11270462.pdf')
# (288, 154, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\11677012.pdf')
# (289, 155, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\12085736.pdf')
# (290, 39, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13328680.pdf')
# (291, 54, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13343786.pdf')
# (292, 95, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13503650.pdf')
# (293, 104, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\13837784.pdf')
# (294, 55, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14036515.pdf')
# (295, 156, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14209965.pdf')
# (296, 21, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14556869.pdf')
# (297, 157, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14761906.pdf')
# (298, 44, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14771530.pdf')
# (299, 103, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\14945250.pdf')
# (300, 153, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\15226699.pdf')
# (301, 115, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\15353911.pdf')
# (302, 23, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\15484097.pdf')
# (303, 158, 'DIGITAL-MEDIA', 'archive\\data\\data\\DIGITAL-MEDIA\\16276121.pdf')
# (304, 159, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10030015.pdf')
# (305, 147, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10219099.pdf')
# (306, 160, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10624813.pdf')
# (307, 82, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10712803.pdf')
# (308, 22, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\10985403.pdf')
# (309, 161, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\11890896.pdf')
# (310, 41, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\11981094.pdf')
# (311, 22, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12011623.pdf')
# (312, 143, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12022566.pdf')
# (313, 2, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12472574.pdf')
# (314, 162, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12488356.pdf')
# (315, 127, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12518008.pdf')
# (316, 87, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\12748557.pdf')
# (317, 2, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\13149176.pdf')
# (318, 77, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\13264796.pdf')
# (319, 163, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\14049846.pdf')
# (320, 30, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\14206561.pdf')
# (321, 17, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\14554542.pdf')
# (322, 90, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\15139979.pdf')
# (323, 164, 'ENGINEERING', 'archive\\data\\data\\ENGINEERING\\15601399.pdf')
# (324, 101, 'FINANCE', 'archive\\data\\data\\FINANCE\\10549585.pdf')
# (325, 88, 'FINANCE', 'archive\\data\\data\\FINANCE\\11441764.pdf')
# (326, 45, 'FINANCE', 'archive\\data\\data\\FINANCE\\11490673.pdf')
# (327, 32, 'FINANCE', 'archive\\data\\data\\FINANCE\\11877150.pdf')
# (328, 46, 'FINANCE', 'archive\\data\\data\\FINANCE\\12071138.pdf')
# (329, 165, 'FINANCE', 'archive\\data\\data\\FINANCE\\12858898.pdf')
# (330, 166, 'FINANCE', 'archive\\data\\data\\FINANCE\\14106638.pdf')
# (331, 129, 'FINANCE', 'archive\\data\\data\\FINANCE\\14181049.pdf')
# (332, 119, 'FINANCE', 'archive\\data\\data\\FINANCE\\14408510.pdf')
# (333, 10, 'FINANCE', 'archive\\data\\data\\FINANCE\\14413148.pdf')
# (334, 50, 'FINANCE', 'archive\\data\\data\\FINANCE\\14722634.pdf')
# (335, 167, 'FINANCE', 'archive\\data\\data\\FINANCE\\15011085.pdf')
# (336, 168, 'FINANCE', 'archive\\data\\data\\FINANCE\\15224503.pdf')
# (337, 169, 'FINANCE', 'archive\\data\\data\\FINANCE\\15717923.pdf')
# (338, 6, 'FINANCE', 'archive\\data\\data\\FINANCE\\15792052.pdf')
# (339, 59, 'FINANCE', 'archive\\data\\data\\FINANCE\\15891494.pdf')
# (340, 170, 'FINANCE', 'archive\\data\\data\\FINANCE\\16426777.pdf')
# (341, 136, 'FINANCE', 'archive\\data\\data\\FINANCE\\16449850.pdf')
# (342, 171, 'FINANCE', 'archive\\data\\data\\FINANCE\\17392859.pdf')
# (343, 172, 'FINANCE', 'archive\\data\\data\\FINANCE\\17775916.pdf')
# (344, 76, 'FITNESS', 'archive\\data\\data\\FITNESS\\10235429.pdf')
# (345, 173, 'FITNESS', 'archive\\data\\data\\FITNESS\\10268614.pdf')
# (346, 171, 'FITNESS', 'archive\\data\\data\\FITNESS\\10333051.pdf')
# (347, 119, 'FITNESS', 'archive\\data\\data\\FITNESS\\10428916.pdf')
# (348, 154, 'FITNESS', 'archive\\data\\data\\FITNESS\\10568350.pdf')
# (349, 32, 'FITNESS', 'archive\\data\\data\\FITNESS\\10816645.pdf')
# (350, 165, 'FITNESS', 'archive\\data\\data\\FITNESS\\10969918.pdf')
# (351, 22, 'FITNESS', 'archive\\data\\data\\FITNESS\\11130200.pdf')
# (352, 35, 'FITNESS', 'archive\\data\\data\\FITNESS\\11332602.pdf')
# (353, 51, 'FITNESS', 'archive\\data\\data\\FITNESS\\11522068.pdf')
# (354, 174, 'FITNESS', 'archive\\data\\data\\FITNESS\\12019284.pdf')
# (355, 172, 'FITNESS', 'archive\\data\\data\\FITNESS\\12092347.pdf')
# (356, 24, 'FITNESS', 'archive\\data\\data\\FITNESS\\12695799.pdf')
# (357, 175, 'FITNESS', 'archive\\data\\data\\FITNESS\\12791244.pdf')
# (358, 109, 'FITNESS', 'archive\\data\\data\\FITNESS\\12923795.pdf')
# (359, 174, 'FITNESS', 'archive\\data\\data\\FITNESS\\12938389.pdf')
# (360, 176, 'FITNESS', 'archive\\data\\data\\FITNESS\\13037145.pdf')
# (361, 103, 'FITNESS', 'archive\\data\\data\\FITNESS\\13367322.pdf')
# (362, 26, 'FITNESS', 'archive\\data\\data\\FITNESS\\13675377.pdf')
# (363, 152, 'FITNESS', 'archive\\data\\data\\FITNESS\\14107571.pdf')
# (364, 83, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10062724.pdf')
# (365, 27, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10076271.pdf')
# (366, 14, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10251432.pdf')
# (367, 43, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10466208.pdf')
# (368, 127, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10480456.pdf')
# (369, 21, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\10568183.pdf')
# (370, 37, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11378657.pdf')
# (371, 129, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11605833.pdf')
# (372, 177, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11653906.pdf')
# (373, 54, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\11704150.pdf')
# (374, 50, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12315079.pdf')
# (375, 178, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12333703.pdf')
# (376, 127, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12613221.pdf')
# (377, 147, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\12938200.pdf')
# (378, 179, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\13352113.pdf')
# (379, 74, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\13565152.pdf')
# (380, 63, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\13575312.pdf')
# (381, 108, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\14062078.pdf')
# (382, 85, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\14667957.pdf')
# (383, 62, 'HEALTHCARE', 'archive\\data\\data\\HEALTHCARE\\15499825.pdf')
# (384, 147, 'HR', 'archive\\data\\data\\HR\\10399912.pdf')
# (385, 180, 'HR', 'archive\\data\\data\\HR\\10694288.pdf')
# (386, 11, 'HR', 'archive\\data\\data\\HR\\11480899.pdf')
# (387, 140, 'HR', 'archive\\data\\data\\HR\\11592605.pdf')
# (388, 134, 'HR', 'archive\\data\\data\\HR\\11698189.pdf')
# (389, 156, 'HR', 'archive\\data\\data\\HR\\11763983.pdf')
# (390, 149, 'HR', 'archive\\data\\data\\HR\\11847784.pdf')
# (391, 60, 'HR', 'archive\\data\\data\\HR\\12786012.pdf')
# (392, 30, 'HR', 'archive\\data\\data\\HR\\13376919.pdf')
# (393, 56, 'HR', 'archive\\data\\data\\HR\\13520837.pdf')
# (394, 160, 'HR', 'archive\\data\\data\\HR\\13879043.pdf')
# (395, 67, 'HR', 'archive\\data\\data\\HR\\14225422.pdf')
# (396, 151, 'HR', 'archive\\data\\data\\HR\\14256329.pdf')
# (397, 32, 'HR', 'archive\\data\\data\\HR\\14640322.pdf')
# (398, 125, 'HR', 'archive\\data\\data\\HR\\14886205.pdf')
# (399, 5, 'HR', 'archive\\data\\data\\HR\\15041689.pdf')
# (400, 181, 'HR', 'archive\\data\\data\\HR\\15375009.pdf')
# (401, 182, 'HR', 'archive\\data\\data\\HR\\15575117.pdf')
# (402, 106, 'HR', 'archive\\data\\data\\HR\\15576950.pdf')
# (403, 183, 'HR', 'archive\\data\\data\\HR\\16852973.pdf')
# (404, 99, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10089434.pdf')
# (405, 6, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10247517.pdf')
# (406, 169, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10265057.pdf')
# (407, 173, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10553553.pdf')
# (408, 184, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10641230.pdf')
# (409, 115, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10839851.pdf')
# (410, 32, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\10840430.pdf')
# (411, 157, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\11580408.pdf')
# (412, 106, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\11584809.pdf')
# (413, 153, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\11957080.pdf')
# (414, 167, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12045067.pdf')
# (415, 159, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12334140.pdf')
# (416, 185, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12635195.pdf')
# (417, 148, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\12763627.pdf')
# (418, 113, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13385306.pdf')
# (419, 58, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13405733.pdf')
# (420, 91, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13477922.pdf')
# (421, 110, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\13836471.pdf')
# (422, 136, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\14789139.pdf')
# (423, 33, 'INFORMATION-TECHNOLOGY', 'archive\\data\\data\\INFORMATION-TECHNOLOGY\\15118506.pdf')
# (424, 74, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10070224.pdf')
# (425, 71, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10554045.pdf')
# (426, 127, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10873344.pdf')
# (427, 186, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\10926726.pdf')
# (428, 5, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11160414.pdf')
# (429, 22, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11624880.pdf')
# (430, 159, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11635137.pdf')
# (431, 52, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11842274.pdf')
# (432, 114, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11850315.pdf')
# (433, 24, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\11902276.pdf')
# (434, 169, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12191094.pdf')
# (435, 74, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12237267.pdf')
# (436, 187, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12545844.pdf')
# (437, 7, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12567516.pdf')
# (438, 152, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\12920612.pdf')
# (439, 24, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\13129275.pdf')
# (440, 159, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\13727873.pdf')
# (441, 174, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\13915715.pdf')
# (442, 62, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\14009087.pdf')
# (443, 184, 'PUBLIC-RELATIONS', 'archive\\data\\data\\PUBLIC-RELATIONS\\14128006.pdf')
# (444, 188, 'SALES', 'archive\\data\\data\\SALES\\10138632.pdf')
# (445, 163, 'SALES', 'archive\\data\\data\\SALES\\10464113.pdf')
# (446, 97, 'SALES', 'archive\\data\\data\\SALES\\10603337.pdf')
# (447, 6, 'SALES', 'archive\\data\\data\\SALES\\10724818.pdf')
# (448, 31, 'SALES', 'archive\\data\\data\\SALES\\10898339.pdf')
# (449, 53, 'SALES', 'archive\\data\\data\\SALES\\12082377.pdf')
# (450, 21, 'SALES', 'archive\\data\\data\\SALES\\12351749.pdf')
# (451, 139, 'SALES', 'archive\\data\\data\\SALES\\12696104.pdf')
# (452, 74, 'SALES', 'archive\\data\\data\\SALES\\12820557.pdf')
# (453, 189, 'SALES', 'archive\\data\\data\\SALES\\13178604.pdf')
# (454, 55, 'SALES', 'archive\\data\\data\\SALES\\13348915.pdf')
# (455, 17, 'SALES', 'archive\\data\\data\\SALES\\13637605.pdf')
# (456, 58, 'SALES', 'archive\\data\\data\\SALES\\13812481.pdf')
# (457, 107, 'SALES', 'archive\\data\\data\\SALES\\14267489.pdf')
# (458, 54, 'SALES', 'archive\\data\\data\\SALES\\14358578.pdf')
# (459, 105, 'SALES', 'archive\\data\\data\\SALES\\14381464.pdf')
# (460, 85, 'SALES', 'archive\\data\\data\\SALES\\15273850.pdf')
# (461, 155, 'SALES', 'archive\\data\\data\\SALES\\15581242.pdf')
# (462, 36, 'SALES', 'archive\\data\\data\\SALES\\15620421.pdf')
# (463, 150, 'SALES', 'archive\\data\\data\\SALES\\15765660.pdf')
# (464, 58, 'TEACHER', 'archive\\data\\data\\TEACHER\\10504237.pdf')
# (465, 53, 'TEACHER', 'archive\\data\\data\\TEACHER\\10527994.pdf')
# (466, 29, 'TEACHER', 'archive\\data\\data\\TEACHER\\10909720.pdf')
# (467, 82, 'TEACHER', 'archive\\data\\data\\TEACHER\\11336022.pdf')
# (468, 163, 'TEACHER', 'archive\\data\\data\\TEACHER\\11616482.pdf')
# (469, 144, 'TEACHER', 'archive\\data\\data\\TEACHER\\11943065.pdf')
# (470, 61, 'TEACHER', 'archive\\data\\data\\TEACHER\\12467531.pdf')
# (471, 187, 'TEACHER', 'archive\\data\\data\\TEACHER\\12587973.pdf')
# (472, 111, 'TEACHER', 'archive\\data\\data\\TEACHER\\13087952.pdf')
# (473, 153, 'TEACHER', 'archive\\data\\data\\TEACHER\\13296856.pdf')
# (474, 24, 'TEACHER', 'archive\\data\\data\\TEACHER\\13330982.pdf')
# (475, 3, 'TEACHER', 'archive\\data\\data\\TEACHER\\13583538.pdf')
# (476, 117, 'TEACHER', 'archive\\data\\data\\TEACHER\\13855004.pdf')
# (477, 52, 'TEACHER', 'archive\\data\\data\\TEACHER\\14958913.pdf')
# (478, 25, 'TEACHER', 'archive\\data\\data\\TEACHER\\15850434.pdf')
# (479, 9, 'TEACHER', 'archive\\data\\data\\TEACHER\\15899269.pdf')
# (480, 159, 'TEACHER', 'archive\\data\\data\\TEACHER\\16210888.pdf')
# (481, 9, 'TEACHER', 'archive\\data\\data\\TEACHER\\16270906.pdf')
# (482, 1, 'TEACHER', 'archive\\data\\data\\TEACHER\\16820422.pdf')
# (483, 13, 'TEACHER', 'archive\\data\\data\\TEACHER\\17311685.pdf')
